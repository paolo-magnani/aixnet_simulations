# %%
import numpy as np
import matplotlib.pyplot as plt
from simulated_dipole import *
import pandas as pd

dp = dipole_parameters('EPOS', 3, 1000) 

results, d, beta = dp.evaluate()
res = pd.DataFrame(results)

# uni_d_r = np.unique(res['d_r'])
# uni_beta_r = np.unique(res['beta_r'][(res['beta_r']>0.8)*((res['beta_r']<=2.6))])

# grid = np.zeros((len(uni_beta_r), len(uni_d_r)))

# for i, h in enumerate(uni_beta_r):
#     for j, l in enumerate(uni_d_r):
#         mask = (res['beta_r']==h) & (res['d_r']==l)
#         if np.any(mask):
#             grid[i, j] = res['chisq'][mask]
# Out:
# Model chosen: EPOS
# dipole cutoff: 3
# Number of energy steps in each bin: 1000
# Best parameter evaluation ...
# progress: 0.5 %
# progress: 1.0 %
# progress: 1.5 %
# progress: 2.0 %
# progress: 2.5 %
# progress: 3.0 %
# progress: 3.5 %
# progress: 4.0 %
# progress: 4.5 %
# progress: 5.0 %
# progress: 5.5 %
# progress: 6.0 %
# progress: 6.5 %
# progress: 7.0 %
# progress: 7.5 %
# progress: 8.0 %
# progress: 8.5 %
# progress: 9.0 %
# progress: 9.5 %
# progress: 10.0 %
# progress: 10.5 %
# progress: 11.0 %
# progress: 11.5 %
# progress: 12.0 %
# progress: 12.5 %
# progress: 13.0 %
# progress: 13.5 %
# progress: 14.0 %
# progress: 14.5 %
# progress: 15.0 %
# progress: 15.5 %
# progress: 16.0 %
# progress: 16.5 %
# progress: 17.0 %
# progress: 17.5 %
# progress: 18.0 %
# progress: 18.5 %
# progress: 19.0 %
# progress: 19.5 %
# progress: 20.0 %
# progress: 20.5 %
# progress: 21.0 %
# progress: 21.5 %
# progress: 22.0 %
# progress: 22.5 %
# progress: 23.0 %
# progress: 23.5 %
# progress: 24.0 %
# progress: 24.5 %
# progress: 25.0 %
# progress: 25.5 %
# progress: 26.0 %
# progress: 26.5 %
# progress: 27.0 %
# progress: 27.5 %
# progress: 28.0 %
# progress: 28.5 %
# progress: 29.0 %
# progress: 29.5 %
# progress: 30.0 %
# progress: 30.5 %
# progress: 31.0 %
# progress: 31.5 %
# progress: 32.0 %
# progress: 32.5 %
# progress: 33.0 %
# progress: 33.5 %
# progress: 34.0 %
# progress: 34.5 %
# progress: 35.0 %
# progress: 35.5 %
# progress: 36.0 %
# progress: 36.5 %
# progress: 37.0 %
# progress: 37.5 %
# progress: 38.0 %
# progress: 38.5 %
# progress: 39.0 %
# progress: 39.5 %
# progress: 40.0 %
# progress: 40.5 %
# progress: 41.0 %
# progress: 41.5 %
# progress: 42.0 %
# progress: 42.5 %
# progress: 43.0 %
# progress: 43.5 %
# progress: 44.0 %
# progress: 44.5 %
# progress: 45.0 %
# progress: 45.5 %
# progress: 46.0 %
# progress: 46.5 %
# progress: 47.0 %
# progress: 47.5 %
# progress: 48.0 %
# progress: 48.5 %
# progress: 49.0 %
# progress: 49.5 %
# progress: 50.0 %
# progress: 50.5 %
# progress: 51.0 %
# progress: 51.5 %
# progress: 52.0 %
# progress: 52.5 %
# progress: 53.0 %
# progress: 53.5 %
# progress: 54.0 %
# progress: 54.5 %
# progress: 55.0 %
# progress: 55.5 %
# progress: 56.0 %
# progress: 56.5 %
# progress: 57.0 %
# progress: 57.5 %
# progress: 58.0 %
# progress: 58.5 %
# progress: 59.0 %
# progress: 59.5 %
# progress: 60.0 %
# progress: 60.5 %
# progress: 61.0 %
# progress: 61.5 %
# progress: 62.0 %
# progress: 62.5 %
# progress: 63.0 %
# progress: 63.5 %
# progress: 64.0 %
# progress: 64.5 %
# progress: 65.0 %
# progress: 65.5 %
# progress: 66.0 %
# progress: 66.5 %
# progress: 67.0 %
# progress: 67.5 %
# progress: 68.0 %
# progress: 68.5 %
# progress: 69.0 %
# progress: 69.5 %
# progress: 70.0 %
# progress: 70.5 %
# progress: 71.0 %
# progress: 71.5 %
# progress: 72.0 %
# progress: 72.5 %
# progress: 73.0 %
# progress: 73.5 %
# progress: 74.0 %
# progress: 74.5 %
# progress: 75.0 %
# progress: 75.5 %
# progress: 76.0 %
# progress: 76.5 %
# progress: 77.0 %
# progress: 77.5 %
# progress: 78.0 %
# progress: 78.5 %
# progress: 79.0 %
# progress: 79.5 %
# progress: 80.0 %
# progress: 80.5 %
# progress: 81.0 %
# progress: 81.5 %
# progress: 82.0 %
# progress: 82.5 %
# progress: 83.0 %
# progress: 83.5 %
# progress: 84.0 %
# progress: 84.5 %
# progress: 85.0 %
# progress: 85.5 %
# progress: 86.0 %
# progress: 86.5 %
# progress: 87.0 %
# progress: 87.5 %
# progress: 88.0 %
# progress: 88.5 %
# progress: 89.0 %
# progress: 89.5 %
# progress: 90.0 %
# progress: 90.5 %
# progress: 91.0 %
# progress: 91.5 %
# progress: 92.0 %
# progress: 92.5 %
# progress: 93.0 %
# progress: 93.5 %
# progress: 94.0 %
# progress: 94.5 %
# progress: 95.0 %
# progress: 95.5 %
# progress: 96.0 %
# progress: 96.5 %
# progress: 97.0 %
# progress: 97.5 %
# progress: 98.0 %
# progress: 98.5 %
# progress: 99.0 %
# progress: 99.5 %
# progress: 100.0 %
# Best d_r: [0.0017]
# Best beta_r: [2.1]

# %%
for key, value in results.items():
    print(len(results[key]))

res = pd.DataFrame(results)
res.to_csv('parameters_results_sybill_dmax_1.csv', index=False)
# Out:
# 6000
# 6000
# 6000
# 6000
# 6000
# 6000
# 6000

# %%
res = pd.read_csv('parameters_results_sybill_dmax_3.csv')

uni_d_r = np.unique(res['d_r'])
uni_beta_r = np.unique(res['beta_r'][(res['beta_r']>0.8)*((res['beta_r']<=2.6))])

grid = np.zeros((len(uni_beta_r), len(uni_d_r)))

for i, h in enumerate(uni_beta_r):
    for j, l in enumerate(uni_d_r):
        mask = (res['beta_r']==h) & (res['d_r']==l)
        if np.any(mask):
            grid[i, j] = res['chisq'][mask]
# Out:
# /tmp/ipykernel_1022/2664859314.py:12: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   grid[i, j] = res['chisq'][mask]

# %%
plt.figure(figsize=(10, 6))
plt.title(r'$d_\mathrm{max}=3$')
cmap = plt.cm.plasma_r
plt.imshow((grid)/1, aspect='auto', origin='lower',
           extent=[uni_d_r.min(), uni_d_r.max(),
                    uni_beta_r.min(), uni_beta_r.max()],
            cmap=cmap, vmin=0, vmax=5)
dot_y = uni_beta_r[np.where(grid==np.min(grid))[0]]
dot_x = uni_d_r[np.where(grid==np.min(grid))[1]]
plt.plot(dot_x, dot_y, ls='', marker='o', color='w', markersize=5)
plt.text(dot_x+0.0005, dot_y, rf'$({float(dot_x):.4f},\, {float(dot_y):.1f})$', color='w')
plt.colorbar(label=r'$\chi^2/$ndf')
plt.xlabel(r'$d_R$')
plt.ylabel(r'$\beta_R$')
yticks = np.arange(1.0, 2.6, 0.3)
plt.yticks(yticks, size='medium')
xticks = np.arange(0.002, 0.021, 0.004)
plt.xticks(xticks, size='medium')
plt.show()

np.where(grid==np.min(grid))[0]
print('chi_squared:', np.min(grid))
print('beta:', uni_beta_r[np.where(grid==np.min(grid))[0]])
print('d:', uni_d_r[np.where(grid==np.min(grid))[1]])
# Out:
# /tmp/ipykernel_1022/1761154651.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(dot_x+0.0005, dot_y, rf'$({float(dot_x):.4f},\, {float(dot_y):.1f})$', color='w')
# chi_squared: 0.3763329237798956
# beta: [1.3]
# d: [0.0097]

# %%
res = pd.read_csv('parameters_results_sybill_dmax_1.csv')

uni_d_r = np.unique(res['d_r'])
uni_beta_r = np.unique(res['beta_r'][(res['beta_r']>0.8)*((res['beta_r']<=2.6))])

grid = np.zeros((len(uni_beta_r), len(uni_d_r)))

for i, h in enumerate(uni_beta_r):
    for j, l in enumerate(uni_d_r):
        mask = (res['beta_r']==h) & (res['d_r']==l)
        if np.any(mask):
            grid[i, j] = res['chisq'][mask]
# Out:
# /tmp/ipykernel_1022/1450243481.py:12: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   grid[i, j] = res['chisq'][mask]

# %%
plt.figure(figsize=(10, 6))
plt.title(r'$d_\mathrm{max}=1$')
cmap = plt.cm.plasma_r
plt.imshow((grid)/1, aspect='auto', origin='lower',
           extent=[uni_d_r.min(), uni_d_r.max(),
                    uni_beta_r.min(), uni_beta_r.max()],
            cmap=cmap, vmin=0, vmax=5)
dot_y = uni_beta_r[np.where(grid==np.min(grid))[0]]
dot_x = uni_d_r[np.where(grid==np.min(grid))[1]]
plt.plot(dot_x, dot_y, ls='', marker='o', color='w', markersize=5)
plt.text(dot_x+0.0005, dot_y, rf'$({float(dot_x):.4f},\, {float(dot_y):.1f})$', color='w')
plt.colorbar(label=r'$\chi^2/$ndf')
plt.xlabel(r'$d_R$')
plt.ylabel(r'$\beta_R$')
yticks = np.arange(1.0, 2.6, 0.3)
plt.yticks(yticks, size='medium')
xticks = np.arange(0.002, 0.021, 0.004)
plt.xticks(xticks, size='medium')
plt.show()

np.where(grid==np.min(grid))[0]
print('chi_squared:', np.min(grid))
print('beta:', uni_beta_r[np.where(grid==np.min(grid))[0]])
print('d:', uni_d_r[np.where(grid==np.min(grid))[1]])
# Out:
# /tmp/ipykernel_1022/417156137.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(dot_x+0.0005, dot_y, rf'$({float(dot_x):.4f},\, {float(dot_y):.1f})$', color='w')
# chi_squared: 0.3987300084416726
# beta: [1.3]
# d: [0.0097]
