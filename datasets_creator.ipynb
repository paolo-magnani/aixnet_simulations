# %% [markdown]
# # Code for doing simulations
# Here I upload all the necessary stuff

# %%
import numpy as np
from simulated_dipole import *
import matplotlib.pyplot as plt
import pandas as pd

keys_to_extract = ['dnn_xmax', 'energy', 'mass']

# IN CASE OF AixNet
# input_path = '/mnt/c/Users/paolo/Desktop/LAVORO/data_files/aixnet_sib_all_data.npz'
# data_all = np.load(input_path, allow_pickle=True)
# ddd = {key: data_all[key] for key in data_all.files}


## IN CASE OF KAne
input_kane = '../berenika_dipole/dateset/KAne_EPOS_sims.csv'

kf = pd.read_csv(input_kane)
ddd = {}
ddd['dnn_xmax'] = np.array(kf['Xmax'])
ddd['zenith'] = np.array(np.pi/2 - kf['Zenith'])
ddd['energy'] = np.array(kf['Energy']/1e18)
ddd['primary'] = np.array(kf['Primary'])
ddd['mass'] = np.empty_like(ddd['energy'])
ddd['mass'][np.where(ddd['primary']==0)] = 1.
ddd['mass'][np.where(ddd['primary']==1)] = 4.
ddd['mass'][np.where(ddd['primary']==2)] = 16.
ddd['mass'][np.where(ddd['primary']==3)] = 56.



print(ddd.keys())
print('Number of simulated events:', len(ddd['energy']))

n_samples = 1000
np.random.seed(90)
seed_1 = np.random.randint(1000, size=n_samples)
seed_2 = np.random.randint(1000, size=n_samples)
seed_3 = np.random.randint(1000, size=n_samples)

print('NAns:', np.isnan(ddd['dnn_xmax']).sum())
# Out:
# dict_keys(['dnn_xmax', 'zenith', 'energy', 'primary', 'mass'])
# Number of simulated events: 808809
# NAns: 2

# %%
def remove_nan_entries(d):
    # Create a mask of valid (non-NaN) entries based on one key (e.g., the first one)
    keys = list(d.keys())
    if not keys:
        return d  # empty dict
    
    # Start with all entries being valid
    mask = ~np.isnan(d[keys[0]])

    # Combine masks if any other key has NaNs
    for key in keys[1:]:
        mask &= ~np.isnan(d[key])

    # Apply mask to all entries
    return {key: np.array(d[key])[mask] for key in d}

ddd = {kk: ddd[kk] for kk in keys_to_extract if kk in ddd}
ddd = remove_nan_entries(ddd)
print(len(ddd['energy']))
# Out:
# 808807

# %% [markdown]
# ## Data production cycle

# %%
## classes I need (AixNet)
# mf = mass_fractions()
# es = energy_spectrum()
# smd = SMD_method()

## IN CASE OF KAne
mf = mass_fractions(model='EPOS')
es = energy_spectrum()
smd = SMD_method(model='EPOS')


# final results dictionary
final_results = {'iter': [], 'emin': [], 'light': [], 'heavy': [], 'frac_l': [], 'frac_h': []}

for k in range(n_samples):

    print('Iteration:', k+1, ' of ', n_samples)
    # data_mask = flatten_distr(ddd['energy'], seed=seed_1[k]) # only for AixNet, but not necessary
    # dd = dict_cutter(ddd, data_mask)

    dd = ddd
    print('After the first cut:', len(dd['energy']))

    # extract mass fractions
    mf.seed = seed_2[k]
    mass_mask = mf.extract_all_fractions(np.log10(dd['energy']*1e18), dd['mass'])
    dd = dict_cutter(dd, mass_mask)
    print('After mass fractions:', len(dd['energy']))

    # extract spectrum
    es.seed = seed_3[k]

    temp_dict = [{} for i in range(4)]

    for i in range(len(energies[:-1])):
        enne = energies[i]/1e18
        enneplus = energies[i+1]/1e18
        energy_mask = (dd['energy']>=enne)&(dd['energy']<enneplus)
        temp_dict[i] = dict_cutter(dd, energy_mask)
        spectrum_mask = es.spectrum_fraction(temp_dict[i]['energy']*1e18)
        temp_dict[i] = dict_cutter(temp_dict[i], spectrum_mask)

    dd = dict_paster(temp_dict)
    print('After energy spectrum:', len(dd['energy']))

    # define charge
    dd['charge'] = np.empty_like(dd['mass'])
    for mass in names:
        dd['charge'][np.where(dd['mass']==names[mass])]=charges[mass]

    generate_xmax19(dd, 'dnn_xmax', 'energy')
    print('NAns:', np.isnan(dd['dnn_xmax']).sum())

    # plt.figure(figsize=(10,6))
    # #plt.title('Simulated data')
    # plt.scatter(dd['energy']*1e18, dd['xmax19'], alpha=0.3, color='k')
    # plt.xlabel(r'energy / eV')
    # plt.ylabel(r'$X_\mathrm{max} / \mathrm{(g \, cm^{-2})}$')
    # plt.xscale('log')
    # plt.ylim(600, 1200)
    # plt.xlim(2.5e18, 150e18)
    # plt.show()
    
    # estimate best quantiles
    thres_values = np.linspace(np.min(dd['xmax19']), np.max(dd['xmax19']), 27)
    # print(thres_values)
    res = { 'emin': [], 
            'light': [], 
            'heavy': [], 
            'N_light': [],
            'N_heavy': [],
            'N_tot': [],
            'SMD': [],
            }
    
    for ee in range(len(energies)-1):
        e_min = energies[ee]/1e18
        e_max =energies[ee+1]/1e18


        # extract energy range
        e_mask = (dd['energy']<e_max)&(dd['energy']>=e_min)
        data = dict_cutter(dd, e_mask)

        for i in range(1, len(thres_values) - 2):
            thres_h = thres_values[i]

            for j in range(i + 1, len(thres_values) - 1):

                thres_l = thres_values[j]
                mask_h = (data['xmax19']<thres_h)
                mask_l = (data['xmax19']>thres_l)
                light_frac = dict_cutter(data, mask_l)
                heavy_frac = dict_cutter(data, mask_h)

                value = smd.quantify_SMD(light_frac['energy'], light_frac['charge'], heavy_frac['energy'], heavy_frac['charge'], d_max=1)
                A_l = np.sum(np.log(light_frac['mass']))
                A_h = np.sum(np.log(heavy_frac['mass']))

                res['emin'].append(e_min)
                res['light'].append(thres_l)
                res['heavy'].append(thres_h)
                res['SMD'].append(value)
                res['N_light'].append(len(light_frac['xmax19']))
                res['N_heavy'].append(len(heavy_frac['xmax19']))
                res['N_tot'].append(len(data['xmax19']))

    for key, value in res.items():
        res[key] = np.array(value)

    # format final results
    for l in range(len(energies[:-1])):
        emin_val = energies[l] / 1e18
        mask = res['emin'] == emin_val

        if not np.any(mask):
            print(f"[WARNING] No SMD entries found for energy bin {emin_val:.2f} EeV (iteration {k})")
            continue

        smd_vals = res['SMD'][mask]
        if len(smd_vals) == 0 or np.all(np.isnan(smd_vals)):
            print(f"[WARNING] SMD array is empty or NaN for energy bin {emin_val:.2f} EeV (iteration {k})")
            continue

        max_pos = np.argmax(smd_vals)
        valid_indices = np.where(mask)[0]
        if len(valid_indices) == 0:
            print(f"[WARNING] No valid indices found after masking for {emin_val:.2f} EeV (iteration {k})")
            continue

        idx = valid_indices[max_pos]

        n_tot = res['N_tot'][idx]
        n_light = res['N_light'][idx]
        n_heavy = res['N_heavy'][idx]

        if n_tot == 0:
            print(f"[WARNING] Total events is zero for energy bin {emin_val:.2f} EeV (iteration {k})")
            frac_l = np.nan
            frac_h = np.nan
        else:
            frac_l = n_light / n_tot
            frac_h = n_heavy / n_tot

        final_results['iter'].append(k)
        final_results['emin'].append(emin_val)
        final_results['light'].append(res['light'][idx])
        final_results['heavy'].append(res['heavy'][idx])
        final_results['frac_l'].append(frac_l)
        final_results['frac_h'].append(frac_h)




# Convert to pandas DataFrame
df_results = pd.DataFrame(final_results)
display(df_results)
df_results.to_csv("final_results_kane.csv", index=False)
# Out:
# Iteration: 1  of  1000
# After the first cut: 808807
# After mass fractions: 198124
# After energy spectrum: 49540
# NAns: 0
# Iteration: 2  of  1000
# After the first cut: 808807
# After mass fractions: 198432
# After energy spectrum: 49341
# NAns: 0
# Iteration: 3  of  1000
# After the first cut: 808807
# After mass fractions: 198902
# After energy spectrum: 49788
# NAns: 0
# Iteration: 4  of  1000
# After the first cut: 808807
# After mass fractions: 198509
# After energy spectrum: 49799
# NAns: 0
# Iteration: 5  of  1000
# After the first cut: 808807
# After mass fractions: 198924
# After energy spectrum: 49675
# NAns: 0
# Iteration: 6  of  1000
# After the first cut: 808807
# After mass fractions: 198459
# After energy spectrum: 49386
# NAns: 0
# Iteration: 7  of  1000
# After the first cut: 808807
# After mass fractions: 198392
# After energy spectrum: 49552
# NAns: 0
# Iteration: 8  of  1000
# After the first cut: 808807
# After mass fractions: 198883
# After energy spectrum: 49632
# NAns: 0
# Iteration: 9  of  1000
# After the first cut: 808807
# After mass fractions: 198371
# After energy spectrum: 49548
# NAns: 0
# Iteration: 10  of  1000
# After the first cut: 808807
# After mass fractions: 198758
# After energy spectrum: 49632
# NAns: 0
# Iteration: 11  of  1000
# After the first cut: 808807
# After mass fractions: 198285
# After energy spectrum: 49334
# NAns: 0
# Iteration: 12  of  1000
# After the first cut: 808807
# After mass fractions: 198345
# After energy spectrum: 49572
# NAns: 0
# Iteration: 13  of  1000
# After the first cut: 808807
# After mass fractions: 198612
# After energy spectrum: 49794
# NAns: 0
# Iteration: 14  of  1000
# After the first cut: 808807
# After mass fractions: 198660
# After energy spectrum: 49693
# NAns: 0
# Iteration: 15  of  1000
# After the first cut: 808807
# After mass fractions: 199462
# After energy spectrum: 49645
# NAns: 0
# Iteration: 16  of  1000
# After the first cut: 808807
# After mass fractions: 198701
# After energy spectrum: 49444
# NAns: 0
# Iteration: 17  of  1000
# After the first cut: 808807
# After mass fractions: 198492
# After energy spectrum: 49791
# NAns: 0
# Iteration: 18  of  1000
# After the first cut: 808807
# After mass fractions: 198879
# After energy spectrum: 49518
# NAns: 0
# Iteration: 19  of  1000
# After the first cut: 808807
# After mass fractions: 198388
# After energy spectrum: 49618
# NAns: 0
# Iteration: 20  of  1000
# After the first cut: 808807
# After mass fractions: 198678
# After energy spectrum: 49732
# NAns: 0
# Iteration: 21  of  1000
# After the first cut: 808807
# After mass fractions: 198630
# After energy spectrum: 49493
# NAns: 0
# Iteration: 22  of  1000
# After the first cut: 808807
# After mass fractions: 198169
# After energy spectrum: 49397
# NAns: 0
# Iteration: 23  of  1000
# After the first cut: 808807
# After mass fractions: 198559
# After energy spectrum: 49841
# NAns: 0
# Iteration: 24  of  1000
# After the first cut: 808807
# After mass fractions: 198789
# After energy spectrum: 49510
# NAns: 0
# Iteration: 25  of  1000
# After the first cut: 808807
# After mass fractions: 198818
# After energy spectrum: 49701
# NAns: 0
# Iteration: 26  of  1000
# After the first cut: 808807
# After mass fractions: 198757
# After energy spectrum: 49519
# NAns: 0
# Iteration: 27  of  1000
# After the first cut: 808807
# After mass fractions: 198450
# After energy spectrum: 49583
# NAns: 0
# Iteration: 28  of  1000
# After the first cut: 808807
# After mass fractions: 198506
# After energy spectrum: 49565
# NAns: 0
# Iteration: 29  of  1000
# After the first cut: 808807
# After mass fractions: 198113
# After energy spectrum: 49226
# NAns: 0
# Iteration: 30  of  1000
# After the first cut: 808807
# After mass fractions: 197919
# After energy spectrum: 49316
# NAns: 0
# Iteration: 31  of  1000
# After the first cut: 808807
# After mass fractions: 198708
# After energy spectrum: 49576
# NAns: 0
# Iteration: 32  of  1000
# After the first cut: 808807
# After mass fractions: 197699
# After energy spectrum: 49012
# NAns: 0
# Iteration: 33  of  1000
# After the first cut: 808807
# After mass fractions: 198350
# After energy spectrum: 49424
# NAns: 0
# Iteration: 34  of  1000
# After the first cut: 808807
# After mass fractions: 198720
# After energy spectrum: 49530
# NAns: 0
# Iteration: 35  of  1000
# After the first cut: 808807
# After mass fractions: 198781
# After energy spectrum: 49530
# NAns: 0
# Iteration: 36  of  1000
# After the first cut: 808807
# After mass fractions: 198798
# After energy spectrum: 49503
# NAns: 0
# Iteration: 37  of  1000
# After the first cut: 808807
# After mass fractions: 198447
# After energy spectrum: 49727
# NAns: 0
# Iteration: 38  of  1000
# After the first cut: 808807
# After mass fractions: 198668
# After energy spectrum: 49343
# NAns: 0
# Iteration: 39  of  1000
# After the first cut: 808807
# After mass fractions: 198380
# After energy spectrum: 49600
# NAns: 0
# Iteration: 40  of  1000
# After the first cut: 808807
# After mass fractions: 198502
# After energy spectrum: 49591
# NAns: 0
# Iteration: 41  of  1000
# After the first cut: 808807
# After mass fractions: 197792
# After energy spectrum: 49378
# NAns: 0
# Iteration: 42  of  1000
# After the first cut: 808807
# After mass fractions: 199008
# After energy spectrum: 49588
# NAns: 0
# Iteration: 43  of  1000
# After the first cut: 808807
# After mass fractions: 198476
# After energy spectrum: 49413
# NAns: 0
# Iteration: 44  of  1000
# After the first cut: 808807
# After mass fractions: 198771
# After energy spectrum: 49593
# NAns: 0
# Iteration: 45  of  1000
# After the first cut: 808807
# After mass fractions: 198646
# After energy spectrum: 49670
# NAns: 0
# Iteration: 46  of  1000
# Iteration: 228  of  1000
# After the first cut: 808807
# After mass fractions: 198350
# After energy spectrum: 49227
# NAns: 0
# Iteration: 229  of  1000
# After the first cut: 808807
# After mass fractions: 198092
# After energy spectrum: 49776
# NAns: 0
# Iteration: 230  of  1000
# After the first cut: 808807
# After mass fractions: 198276
# After energy spectrum: 49488
# NAns: 0
# Iteration: 231  of  1000
# After the first cut: 808807
# After mass fractions: 197966
# After energy spectrum: 49053
# NAns: 0
# Iteration: 232  of  1000
# After the first cut: 808807
# After mass fractions: 198367
# After energy spectrum: 49600
# NAns: 0
# Iteration: 233  of  1000
# After the first cut: 808807
# After mass fractions: 198499
# After energy spectrum: 49557
# NAns: 0
# Iteration: 234  of  1000
# After the first cut: 808807
# After mass fractions: 198604
# After energy spectrum: 49288
# NAns: 0
# Iteration: 235  of  1000
# After the first cut: 808807
# After mass fractions: 198561
# After energy spectrum: 49357
# NAns: 0
# Iteration: 236  of  1000
# After the first cut: 808807
# After mass fractions: 198860
# After energy spectrum: 49573
# NAns: 0
# Iteration: 237  of  1000
# After the first cut: 808807
# After mass fractions: 198351
# After energy spectrum: 49695
# NAns: 0
# Iteration: 238  of  1000
# After the first cut: 808807
# After mass fractions: 198753
# After energy spectrum: 49714
# NAns: 0
# Iteration: 239  of  1000
# After the first cut: 808807
# After mass fractions: 198341
# After energy spectrum: 49139
# NAns: 0
# Iteration: 240  of  1000
# After the first cut: 808807
# After mass fractions: 198529
# After energy spectrum: 49434
# NAns: 0
# Iteration: 241  of  1000
# After the first cut: 808807
# After mass fractions: 198543
# After energy spectrum: 49437
# NAns: 0
# Iteration: 242  of  1000
# After the first cut: 808807
# After mass fractions: 198862
# After energy spectrum: 49645
# NAns: 0
# Iteration: 243  of  1000
# After the first cut: 808807
# After mass fractions: 198154
# After energy spectrum: 49417
# NAns: 0
# Iteration: 244  of  1000
# After the first cut: 808807
# After mass fractions: 198707
# After energy spectrum: 49595
# NAns: 0
# Iteration: 245  of  1000
# After the first cut: 808807
# After mass fractions: 198416
# After energy spectrum: 49395
# NAns: 0
# Iteration: 246  of  1000
# After the first cut: 808807
# After mass fractions: 199563
# After energy spectrum: 49728
# NAns: 0
# Iteration: 247  of  1000
# After the first cut: 808807
# After mass fractions: 198681
# After energy spectrum: 49329
# NAns: 0
# Iteration: 248  of  1000
# After the first cut: 808807
# After mass fractions: 198856
# After energy spectrum: 49492
# NAns: 0
# Iteration: 249  of  1000
# After the first cut: 808807
# After mass fractions: 198243
# After energy spectrum: 49513
# NAns: 0
# Iteration: 250  of  1000
# After the first cut: 808807
# After mass fractions: 198002
# After energy spectrum: 49222
# NAns: 0
# Iteration: 251  of  1000
# After the first cut: 808807
# After mass fractions: 198980
# After energy spectrum: 49650
# NAns: 0
# Iteration: 252  of  1000
# After the first cut: 808807
# After mass fractions: 198216
# After energy spectrum: 49831
# NAns: 0
# Iteration: 253  of  1000
# After the first cut: 808807
# After mass fractions: 198337
# After energy spectrum: 49366
# NAns: 0
# Iteration: 280  of  1000
# After the first cut: 808807
# After mass fractions: 199268
# After energy spectrum: 49737
# NAns: 0
# Iteration: 281  of  1000
# After the first cut: 808807
# After mass fractions: 198074
# After energy spectrum: 49478
# NAns: 0
# Iteration: 282  of  1000
# After the first cut: 808807
# After mass fractions: 198432
# After energy spectrum: 49512
# NAns: 0
# Iteration: 283  of  1000
# After the first cut: 808807
# After mass fractions: 199045
# After energy spectrum: 49842
# NAns: 0
# Iteration: 284  of  1000
# After the first cut: 808807
# After mass fractions: 199031
# After energy spectrum: 49459
# NAns: 0
# Iteration: 285  of  1000
# After the first cut: 808807
# After mass fractions: 198761
# After energy spectrum: 49742
# NAns: 0
# Iteration: 286  of  1000
# After the first cut: 808807
# After mass fractions: 198476
# After energy spectrum: 49794
# NAns: 0
# Iteration: 287  of  1000
# After the first cut: 808807
# After mass fractions: 198781
# After energy spectrum: 49590
# NAns: 0
# Iteration: 288  of  1000
# After the first cut: 808807
# After mass fractions: 198188
# After energy spectrum: 49455
# NAns: 0
# Iteration: 289  of  1000
# After the first cut: 808807
# After mass fractions: 198360
# After energy spectrum: 49738
# NAns: 0
# Iteration: 290  of  1000
# After the first cut: 808807
# After mass fractions: 198943
# After energy spectrum: 49908
# NAns: 0
# Iteration: 291  of  1000
# After the first cut: 808807
# After mass fractions: 199031
# After energy spectrum: 49948
# NAns: 0
# Iteration: 292  of  1000
# After the first cut: 808807
# After mass fractions: 198508
# After energy spectrum: 49779
# NAns: 0
# Iteration: 293  of  1000
# After the first cut: 808807
# After mass fractions: 198572
# After energy spectrum: 49779
# NAns: 0
# Iteration: 294  of  1000
# After the first cut: 808807
# After mass fractions: 198658
# After energy spectrum: 49306
# NAns: 0
# Iteration: 295  of  1000
# After the first cut: 808807
# After mass fractions: 198173
# After energy spectrum: 49439
# NAns: 0
# Iteration: 296  of  1000
# After the first cut: 808807
# After mass fractions: 198332
# After energy spectrum: 49577
# NAns: 0
# Iteration: 297  of  1000
# After the first cut: 808807
# After mass fractions: 198610
# After energy spectrum: 49223
# NAns: 0
# Iteration: 298  of  1000
# After the first cut: 808807
# After mass fractions: 197887
# After energy spectrum: 49264
# NAns: 0
# Iteration: 299  of  1000
# After the first cut: 808807
# After mass fractions: 198575
# After energy spectrum: 49152
# NAns: 0
# Iteration: 300  of  1000
# After the first cut: 808807
# After mass fractions: 198528
# After energy spectrum: 49412
# NAns: 0
# Iteration: 301  of  1000
# After the first cut: 808807
# After mass fractions: 198903
# After energy spectrum: 49649
# NAns: 0
# Iteration: 302  of  1000
# After the first cut: 808807
# After mass fractions: 198671
# After energy spectrum: 49638
# NAns: 0
# Iteration: 303  of  1000
# After the first cut: 808807
# After mass fractions: 198854
# After energy spectrum: 49535
# NAns: 0
# Iteration: 304  of  1000
# After the first cut: 808807
# After mass fractions: 198765
# After energy spectrum: 49600
# NAns: 0
# Iteration: 305  of  1000
# After the first cut: 808807
# After mass fractions: 198499
# After energy spectrum: 49632
# NAns: 0
# Iteration: 358  of  1000
# After the first cut: 808807
# After mass fractions: 198489
# After energy spectrum: 49290
# NAns: 0
# Iteration: 359  of  1000
# After the first cut: 808807
# After mass fractions: 198461
# After energy spectrum: 49200
# NAns: 0
# Iteration: 360  of  1000
# After the first cut: 808807
# After mass fractions: 199083
# After energy spectrum: 49527
# NAns: 0
# Iteration: 361  of  1000
# After the first cut: 808807
# After mass fractions: 198188
# After energy spectrum: 49411
# NAns: 0
# Iteration: 362  of  1000
# After the first cut: 808807
# After mass fractions: 198256
# After energy spectrum: 49067
# NAns: 0
# Iteration: 363  of  1000
# After the first cut: 808807
# After mass fractions: 198446
# After energy spectrum: 49431
# NAns: 0
# Iteration: 364  of  1000
# After the first cut: 808807
# After mass fractions: 198900
# After energy spectrum: 49429
# NAns: 0
# Iteration: 365  of  1000
# After the first cut: 808807
# After mass fractions: 198185
# After energy spectrum: 49322
# NAns: 0
# Iteration: 366  of  1000
# After the first cut: 808807
# After mass fractions: 198206
# After energy spectrum: 49387
# NAns: 0
# Iteration: 367  of  1000
# After the first cut: 808807
# After mass fractions: 198447
# After energy spectrum: 49659
# NAns: 0
# Iteration: 368  of  1000
# After the first cut: 808807
# After mass fractions: 199215
# After energy spectrum: 49613
# NAns: 0
# Iteration: 369  of  1000
# After the first cut: 808807
# After mass fractions: 198983
# After energy spectrum: 49538
# NAns: 0
# Iteration: 370  of  1000
# After the first cut: 808807
# After mass fractions: 199091
# After energy spectrum: 49966
# NAns: 0
# Iteration: 371  of  1000
# After the first cut: 808807
# After mass fractions: 198929
# After energy spectrum: 49866
# NAns: 0
# Iteration: 372  of  1000
# After the first cut: 808807
# After mass fractions: 198924
# After energy spectrum: 49329
# NAns: 0
# Iteration: 373  of  1000
# After the first cut: 808807
# After mass fractions: 198224
# After energy spectrum: 49270
# NAns: 0
# Iteration: 374  of  1000
# After the first cut: 808807
# After mass fractions: 198124
# After energy spectrum: 49691
# NAns: 0
# Iteration: 375  of  1000
# After the first cut: 808807
# After mass fractions: 198592
# After energy spectrum: 49471
# NAns: 0
# Iteration: 376  of  1000
# After the first cut: 808807
# After mass fractions: 198276
# After energy spectrum: 49451
# NAns: 0
# Iteration: 377  of  1000
# After the first cut: 808807
# After mass fractions: 198619
# After energy spectrum: 49559
# NAns: 0
# Iteration: 378  of  1000
# After the first cut: 808807
# After mass fractions: 199191
# After energy spectrum: 49906
# NAns: 0
# Iteration: 379  of  1000
# After the first cut: 808807
# After mass fractions: 198161
# After energy spectrum: 49336
# NAns: 0
# Iteration: 380  of  1000
# After the first cut: 808807
# After mass fractions: 198119
# After energy spectrum: 49543
# NAns: 0
# Iteration: 381  of  1000
# After the first cut: 808807
# After mass fractions: 198476
# After energy spectrum: 49794
# NAns: 0
# Iteration: 382  of  1000
# After the first cut: 808807
# After mass fractions: 198793
# After energy spectrum: 49508
# NAns: 0
# Iteration: 383  of  1000
# After the first cut: 808807
# After mass fractions: 198455
# After energy spectrum: 49370
# NAns: 0
# Iteration: 384  of  1000
# After the first cut: 808807
# After mass fractions: 198727
# After energy spectrum: 49654
# NAns: 0
# Iteration: 385  of  1000
# After the first cut: 808807
# After mass fractions: 198608
# After energy spectrum: 49364
# NAns: 0
# Iteration: 386  of  1000
# After the first cut: 808807
# After mass fractions: 198290
# After energy spectrum: 49698
# NAns: 0
# Iteration: 387  of  1000
# After the first cut: 808807
# After mass fractions: 198122
# After energy spectrum: 49258
# NAns: 0
# Iteration: 388  of  1000
# After the first cut: 808807
# After mass fractions: 198025
# After energy spectrum: 49201
# NAns: 0
# Iteration: 389  of  1000
# After the first cut: 808807
# After mass fractions: 198557
# After energy spectrum: 49559
# NAns: 0
# Iteration: 390  of  1000
# After the first cut: 808807
# After mass fractions: 198405
# After energy spectrum: 49577
# NAns: 0
# Iteration: 391  of  1000
# After the first cut: 808807
# After mass fractions: 198646
# After energy spectrum: 49670
# NAns: 0
# Iteration: 392  of  1000
# After the first cut: 808807
# After mass fractions: 198519
# After energy spectrum: 49512
# NAns: 0
# Iteration: 393  of  1000
# After the first cut: 808807
# After mass fractions: 198715
# After energy spectrum: 49629
# NAns: 0
# Iteration: 394  of  1000
# After the first cut: 808807
# After mass fractions: 198809
# After energy spectrum: 49599
# NAns: 0
# Iteration: 395  of  1000
# After the first cut: 808807
# After mass fractions: 199178
# After energy spectrum: 49807
# NAns: 0
# Iteration: 396  of  1000
# After the first cut: 808807
# After mass fractions: 198585
# After energy spectrum: 49592
# NAns: 0
# Iteration: 397  of  1000
# After the first cut: 808807
# After mass fractions: 198330
# After energy spectrum: 49090
# NAns: 0
# Iteration: 398  of  1000
# After the first cut: 808807
# After mass fractions: 198662
# After energy spectrum: 49440
# NAns: 0
# Iteration: 399  of  1000
# After the first cut: 808807
# After mass fractions: 198520
# After energy spectrum: 49424
# NAns: 0
# Iteration: 400  of  1000
# After the first cut: 808807
# After mass fractions: 198597
# After energy spectrum: 49520
# NAns: 0
# Iteration: 401  of  1000
# After the first cut: 808807
# After mass fractions: 199178
# After energy spectrum: 49807
# NAns: 0
# Iteration: 402  of  1000
# After the first cut: 808807
# After mass fractions: 198586
# After energy spectrum: 49648
# NAns: 0
# Iteration: 403  of  1000
# After the first cut: 808807
# After mass fractions: 199309
# After energy spectrum: 49638
# NAns: 0
# Iteration: 404  of  1000
# After the first cut: 808807
# After mass fractions: 198758
# After energy spectrum: 49632
# NAns: 0
# Iteration: 405  of  1000
# ...
# NAns: 0
# Iteration: 873  of  1000
# After the first cut: 808807
# After mass fractions: 198421
# After energy spectrum: 49065
# NAns: 0
# Iteration: 874  of  1000
# After the first cut: 808807
# After mass fractions: 198245
# After energy spectrum: 49420
# NAns: 0
# Iteration: 875  of  1000
# After the first cut: 808807
# After mass fractions: 198458
# After energy spectrum: 49520
# NAns: 0
# Iteration: 876  of  1000
# After the first cut: 808807
# After mass fractions: 199172
# After energy spectrum: 49816
# NAns: 0
# Iteration: 877  of  1000
# After the first cut: 808807
# After mass fractions: 199073
# After energy spectrum: 49837
# NAns: 0
# Iteration: 878  of  1000
# After the first cut: 808807
# After mass fractions: 198686
# After energy spectrum: 49669
# NAns: 0
# Iteration: 879  of  1000
# After the first cut: 808807
# After mass fractions: 198544
# After energy spectrum: 49422
# NAns: 0
# Iteration: 880  of  1000
# After the first cut: 808807
# After mass fractions: 198571
# After energy spectrum: 49620
# NAns: 0
# Iteration: 881  of  1000
# After the first cut: 808807
# After mass fractions: 198586
# After energy spectrum: 49940
# NAns: 0
# Iteration: 882  of  1000
# After the first cut: 808807
# After mass fractions: 198960
# After energy spectrum: 49745
# NAns: 0
# Iteration: 883  of  1000
# After the first cut: 808807
# After mass fractions: 199481
# After energy spectrum: 49688
# NAns: 0
# Iteration: 884  of  1000
# After the first cut: 808807
# After mass fractions: 198380
# After energy spectrum: 49600
# NAns: 0
# Iteration: 885  of  1000
# After the first cut: 808807
# After mass fractions: 199215
# After energy spectrum: 49613
# NAns: 0
# Iteration: 886  of  1000
# After the first cut: 808807
# After mass fractions: 198849
# After energy spectrum: 49369
# NAns: 0
# Iteration: 887  of  1000
# After the first cut: 808807
# After mass fractions: 198275
# After energy spectrum: 49737
# NAns: 0
# Iteration: 888  of  1000
# After the first cut: 808807
# After mass fractions: 198680
# After energy spectrum: 49269
# NAns: 0
# Iteration: 889  of  1000
# After the first cut: 808807
# After mass fractions: 198179
# After energy spectrum: 49315
# NAns: 0
# Iteration: 890  of  1000
# After the first cut: 808807
# After mass fractions: 198654
# After energy spectrum: 49662
# NAns: 0
# Iteration: 891  of  1000
# After the first cut: 808807
# After mass fractions: 198408
# After energy spectrum: 49722
# NAns: 0
# Iteration: 892  of  1000
# After the first cut: 808807
# After mass fractions: 198353
# After energy spectrum: 49409
# NAns: 0
# Iteration: 893  of  1000
# After the first cut: 808807
# After mass fractions: 199133
# After energy spectrum: 49580
# NAns: 0
# Iteration: 894  of  1000
# After the first cut: 808807
# After mass fractions: 198312
# After energy spectrum: 49480
# NAns: 0
# Iteration: 895  of  1000
# After the first cut: 808807
# After mass fractions: 198813
# After energy spectrum: 49429
# NAns: 0
# Iteration: 896  of  1000
# After the first cut: 808807
# After mass fractions: 198321
# After energy spectrum: 49458
# NAns: 0
# Iteration: 897  of  1000
# After the first cut: 808807
# After mass fractions: 198759
# After energy spectrum: 49779
# NAns: 0
# Iteration: 898  of  1000
# After the first cut: 808807
# After mass fractions: 198115
# After energy spectrum: 49181
# NAns: 0
# Iteration: 899  of  1000
# After the first cut: 808807
# After mass fractions: 198602
# After energy spectrum: 49495
# NAns: 0
# Iteration: 900  of  1000
# After the first cut: 808807
# After mass fractions: 198216
# After energy spectrum: 49831
# NAns: 0
# Iteration: 901  of  1000
# After the first cut: 808807
# After mass fractions: 198724
# After energy spectrum: 49484
# NAns: 0
# Iteration: 902  of  1000
# After the first cut: 808807
# After mass fractions: 198294
# After energy spectrum: 49419
# NAns: 0
# Iteration: 903  of  1000
# After the first cut: 808807
# After mass fractions: 198380
# After energy spectrum: 49594
# NAns: 0
# Iteration: 904  of  1000
# After the first cut: 808807
# After mass fractions: 198900
# After energy spectrum: 49292
# NAns: 0
# Iteration: 905  of  1000
# After the first cut: 808807
# After mass fractions: 199169
# After energy spectrum: 49648
# NAns: 0
# Iteration: 906  of  1000
# After the first cut: 808807
# After mass fractions: 198159
# After energy spectrum: 49464
# NAns: 0
# Iteration: 907  of  1000
# After the first cut: 808807
# After mass fractions: 199057
# After energy spectrum: 49839
# NAns: 0
# Iteration: 908  of  1000
# After the first cut: 808807
# After mass fractions: 198529
# After energy spectrum: 49434
# NAns: 0
# Iteration: 909  of  1000
# After the first cut: 808807
# After mass fractions: 197979
# After energy spectrum: 49659
# NAns: 0
# Iteration: 910  of  1000
# After the first cut: 808807
# After mass fractions: 198237
# After energy spectrum: 49221
# NAns: 0
# Iteration: 911  of  1000
# After the first cut: 808807
# After mass fractions: 198593
# After energy spectrum: 49530
# NAns: 0
# Iteration: 912  of  1000
# After the first cut: 808807
# After mass fractions: 198794
# After energy spectrum: 49630
# NAns: 0
# Iteration: 913  of  1000
# After the first cut: 808807
# After mass fractions: 198465
# After energy spectrum: 49249
# NAns: 0
# Iteration: 914  of  1000
# After the first cut: 808807
# After mass fractions: 198223
# After energy spectrum: 49571
# NAns: 0
# Iteration: 915  of  1000
# After the first cut: 808807
# After mass fractions: 199078
# After energy spectrum: 49624
# NAns: 0
# Iteration: 916  of  1000
# After the first cut: 808807
# After mass fractions: 199180
# After energy spectrum: 49658
# NAns: 0
# Iteration: 917  of  1000
# After the first cut: 808807
# After mass fractions: 198621
# After energy spectrum: 49554
# NAns: 0
# Iteration: 918  of  1000
# After the first cut: 808807
# After mass fractions: 198449
# After energy spectrum: 49357
# NAns: 0
# Iteration: 919  of  1000
# After the first cut: 808807
# After mass fractions: 198325
# After energy spectrum: 49585
# NAns: 0
# Iteration: 920  of  1000
# After the first cut: 808807
# After mass fractions: 198307
# After energy spectrum: 49582
# NAns: 0
# Iteration: 921  of  1000
# After the first cut: 808807
# After mass fractions: 199232
# After energy spectrum: 49967
# NAns: 0
# Iteration: 922  of  1000
# After the first cut: 808807
# After mass fractions: 198552
# After energy spectrum: 49512
# NAns: 0
# Iteration: 923  of  1000
# After the first cut: 808807
# After mass fractions: 198704
# After energy spectrum: 49768
# NAns: 0
# Iteration: 924  of  1000
# After the first cut: 808807
# After mass fractions: 198425
# After energy spectrum: 49350
# NAns: 0
# Iteration: 925  of  1000
# After the first cut: 808807
# After mass fractions: 198981
# After energy spectrum: 49683
# NAns: 0
# Iteration: 926  of  1000
# After the first cut: 808807
# After mass fractions: 199056
# After energy spectrum: 49484
# NAns: 0
# Iteration: 927  of  1000
# After the first cut: 808807
# After mass fractions: 198225
# After energy spectrum: 49348
# NAns: 0
# Iteration: 928  of  1000
# After the first cut: 808807
# After mass fractions: 198417
# After energy spectrum: 49521
# NAns: 0
# Iteration: 929  of  1000
# After the first cut: 808807
# After mass fractions: 198942
# After energy spectrum: 49610
# NAns: 0
# Iteration: 930  of  1000
# After the first cut: 808807
# After mass fractions: 198795
# After energy spectrum: 49524
# NAns: 0
# Iteration: 931  of  1000
# After the first cut: 808807
# After mass fractions: 199059
# After energy spectrum: 49673
# NAns: 0
# Iteration: 932  of  1000
# After the first cut: 808807
# After mass fractions: 198405
# After energy spectrum: 49577
# NAns: 0
# Iteration: 933  of  1000
# After the first cut: 808807
# After mass fractions: 199173
# After energy spectrum: 49538
# NAns: 0
# Iteration: 934  of  1000
# After the first cut: 808807
# After mass fractions: 198292
# After energy spectrum: 49477
# NAns: 0
# Iteration: 935  of  1000
# After the first cut: 808807
# After mass fractions: 198726
# After energy spectrum: 49591
# NAns: 0
# Iteration: 936  of  1000
# After the first cut: 808807
# After mass fractions: 198200
# After energy spectrum: 49167
# NAns: 0
# Iteration: 937  of  1000
# After the first cut: 808807
# After mass fractions: 198968
# After energy spectrum: 49774
# NAns: 0
# Iteration: 938  of  1000
# After the first cut: 808807
# After mass fractions: 198449
# After energy spectrum: 49357
# NAns: 0
# Iteration: 939  of  1000
# After the first cut: 808807
# After mass fractions: 198473
# After energy spectrum: 49441
# NAns: 0
# Iteration: 940  of  1000
# After the first cut: 808807
# After mass fractions: 198003
# After energy spectrum: 49518
# NAns: 0
# Iteration: 941  of  1000
# After the first cut: 808807
# After mass fractions: 198440
# After energy spectrum: 49537
# NAns: 0
# Iteration: 942  of  1000
# After the first cut: 808807
# After mass fractions: 199031
# After energy spectrum: 49948
# NAns: 0
# Iteration: 943  of  1000
# After the first cut: 808807
# After mass fractions: 198398
# After energy spectrum: 49545
# NAns: 0
# Iteration: 944  of  1000
# After the first cut: 808807
# After mass fractions: 198260
# After energy spectrum: 49352
# NAns: 0
# Iteration: 945  of  1000
# After the first cut: 808807
# After mass fractions: 198949
# After energy spectrum: 49691
# NAns: 0
# Iteration: 946  of  1000
# After the first cut: 808807
# After mass fractions: 199045
# After energy spectrum: 49702
# NAns: 0
# Iteration: 947  of  1000
# After the first cut: 808807
# After mass fractions: 199056
# After energy spectrum: 49484
# NAns: 0
# Iteration: 948  of  1000
# After the first cut: 808807
# After mass fractions: 198773
# After energy spectrum: 49378
# NAns: 0
# Iteration: 949  of  1000
# After the first cut: 808807
# After mass fractions: 198729
# After energy spectrum: 49672
# NAns: 0
# Iteration: 950  of  1000
# After the first cut: 808807
# After mass fractions: 198460
# After energy spectrum: 49500
# NAns: 0
# Iteration: 951  of  1000
# After the first cut: 808807
# After mass fractions: 198773
# After energy spectrum: 49966
# NAns: 0
# Iteration: 952  of  1000
# After the first cut: 808807
# After mass fractions: 198173
# After energy spectrum: 49299
# NAns: 0
# Iteration: 953  of  1000
# After the first cut: 808807
# After mass fractions: 198722
# After energy spectrum: 49465
# NAns: 0
# Iteration: 954  of  1000
# After the first cut: 808807
# After mass fractions: 199532
# After energy spectrum: 49779
# NAns: 0
# Iteration: 955  of  1000
# After the first cut: 808807
# After mass fractions: 198577
# After energy spectrum: 49675
# NAns: 0
# Iteration: 956  of  1000
# After the first cut: 808807
# After mass fractions: 198608
# After energy spectrum: 49428
# NAns: 0
# Iteration: 957  of  1000
# After the first cut: 808807
# After mass fractions: 198202
# After energy spectrum: 49373
# NAns: 0
# Iteration: 958  of  1000
# After the first cut: 808807
# After mass fractions: 198846
# After energy spectrum: 49382
# NAns: 0
# Iteration: 959  of  1000
# After the first cut: 808807
# After mass fractions: 198855
# After energy spectrum: 49480
# NAns: 0
# Iteration: 960  of  1000
# After the first cut: 808807
# After mass fractions: 198967
# After energy spectrum: 49701
# NAns: 0
# Iteration: 961  of  1000
# After the first cut: 808807
# After mass fractions: 198459
# After energy spectrum: 49670
# NAns: 0
# Iteration: 962  of  1000
# After the first cut: 808807
# After mass fractions: 199514
# After energy spectrum: 49471
# NAns: 0
# Iteration: 963  of  1000
# After the first cut: 808807
# After mass fractions: 198794
# After energy spectrum: 49606
# NAns: 0
# Iteration: 964  of  1000
# After the first cut: 808807
# After mass fractions: 198889
# After energy spectrum: 49504
# NAns: 0
# Iteration: 965  of  1000
# After the first cut: 808807
# After mass fractions: 198345
# After energy spectrum: 49572
# NAns: 0
# Iteration: 966  of  1000
# After the first cut: 808807
# After mass fractions: 198569
# After energy spectrum: 49462
# NAns: 0
# Iteration: 967  of  1000
# After the first cut: 808807
# After mass fractions: 198968
# After energy spectrum: 49745
# NAns: 0
# Iteration: 968  of  1000
# After the first cut: 808807
# After mass fractions: 198833
# After energy spectrum: 49359
# NAns: 0
# Iteration: 969  of  1000
# After the first cut: 808807
# After mass fractions: 198731
# After energy spectrum: 49314
# NAns: 0
# Iteration: 970  of  1000
# After the first cut: 808807
# After mass fractions: 198699
# After energy spectrum: 49387
# NAns: 0
# Iteration: 971  of  1000
# After the first cut: 808807
# After mass fractions: 199241
# After energy spectrum: 49384
# NAns: 0
# Iteration: 972  of  1000
# After the first cut: 808807
# After mass fractions: 198321
# After energy spectrum: 49458
# NAns: 0
# Iteration: 973  of  1000
# After the first cut: 808807
# After mass fractions: 198252
# After energy spectrum: 49508
# NAns: 0
# Iteration: 974  of  1000
# After the first cut: 808807
# After mass fractions: 198695
# After energy spectrum: 49756
# NAns: 0
# Iteration: 975  of  1000
# After the first cut: 808807
# After mass fractions: 198690
# After energy spectrum: 49780
# NAns: 0
# Iteration: 976  of  1000
# After the first cut: 808807
# After mass fractions: 198737
# After energy spectrum: 49759
# NAns: 0
# Iteration: 977  of  1000
# After the first cut: 808807
# After mass fractions: 198730
# After energy spectrum: 49265
# NAns: 0
# Iteration: 978  of  1000
# After the first cut: 808807
# After mass fractions: 198432
# After energy spectrum: 49907
# NAns: 0
# Iteration: 979  of  1000
# After the first cut: 808807
# After mass fractions: 198188
# After energy spectrum: 49455
# NAns: 0
# Iteration: 980  of  1000
# After the first cut: 808807
# After mass fractions: 198473
# After energy spectrum: 49549
# NAns: 0
# Iteration: 981  of  1000
# After the first cut: 808807
# After mass fractions: 198104
# After energy spectrum: 49311
# NAns: 0
# Iteration: 982  of  1000
# After the first cut: 808807
# After mass fractions: 198731
# After energy spectrum: 49225
# NAns: 0
# Iteration: 983  of  1000
# After the first cut: 808807
# After mass fractions: 198156
# After energy spectrum: 49469
# NAns: 0
# Iteration: 984  of  1000
# After the first cut: 808807
# After mass fractions: 198380
# After energy spectrum: 49511
# NAns: 0
# Iteration: 985  of  1000
# After the first cut: 808807
# After mass fractions: 198459
# After energy spectrum: 49386
# NAns: 0
# Iteration: 986  of  1000
# After the first cut: 808807
# After mass fractions: 198509
# After energy spectrum: 49799
# NAns: 0
# Iteration: 987  of  1000
# After the first cut: 808807
# After mass fractions: 198673
# After energy spectrum: 49786
# NAns: 0
# Iteration: 988  of  1000
# After the first cut: 808807
# After mass fractions: 198974
# After energy spectrum: 49748
# NAns: 0
# Iteration: 989  of  1000
# After the first cut: 808807
# After mass fractions: 198765
# After energy spectrum: 49600
# NAns: 0
# Iteration: 990  of  1000
# After the first cut: 808807
# After mass fractions: 198541
# After energy spectrum: 49905
# NAns: 0
# Iteration: 991  of  1000
# After the first cut: 808807
# After mass fractions: 198692
# After energy spectrum: 49575
# NAns: 0
# Iteration: 992  of  1000
# After the first cut: 808807
# After mass fractions: 198443
# After energy spectrum: 49713
# NAns: 0
# Iteration: 993  of  1000
# After the first cut: 808807
# After mass fractions: 198585
# After energy spectrum: 49388
# NAns: 0
# Iteration: 994  of  1000
# After the first cut: 808807
# After mass fractions: 198555
# After energy spectrum: 49535
# NAns: 0
# Iteration: 995  of  1000
# After the first cut: 808807
# After mass fractions: 198414
# After energy spectrum: 49326
# NAns: 0
# Iteration: 996  of  1000
# After the first cut: 808807
# After mass fractions: 197992
# After energy spectrum: 49433
# NAns: 0
# Iteration: 997  of  1000
# After the first cut: 808807
# After mass fractions: 198801
# After energy spectrum: 49288
# NAns: 0
# Iteration: 998  of  1000
# After the first cut: 808807
# After mass fractions: 198577
# After energy spectrum: 49675
# NAns: 0
# Iteration: 999  of  1000
# After the first cut: 808807
# After mass fractions: 198208
# After energy spectrum: 49279
# NAns: 0
# Iteration: 1000  of  1000
# After the first cut: 808807
# After mass fractions: 199223
# After energy spectrum: 49805
# NAns: 0
#       iter  emin       light       heavy    frac_l    frac_h
# 0        0   4.0  797.192914  762.470979  0.321042  0.397759
# 1        0   8.0  797.192914  745.110011  0.218655  0.336831
# 2        0  16.0  797.192914  745.110011  0.133087  0.447288
# 3        0  32.0  779.831946  727.749044  0.114168  0.430016
# 4        1   4.0  813.073862  743.689089  0.218548  0.240137
# ...    ...   ...         ...         ...       ...       ...
# 3995   998  32.0  787.355935  732.539054  0.084569  0.485993
# 3996   999   4.0  813.216820  759.101261  0.224105  0.365247
# 3997   999   8.0  813.216820  741.062742  0.139950  0.292094
# 3998   999  16.0  795.178300  741.062742  0.140285  0.403386
# 3999   999  32.0  795.178300  723.024223  0.062840  0.365963
#
# [4000 rows x 6 columns]
