# %% [markdown]
# # Code for doing simulations
# Here I upload all the necessary stuff

# %%
import numpy as np
from mass_fractions import *
from simulated_dipole import *
import pandas as pd

input_path = '/mnt/c/Users/paolo/Desktop/LAVORO/data_files/aixnet_sib_all_data.npz'
data_all = np.load(input_path, allow_pickle=True)
ddd = {key: data_all[key] for key in data_all.files}

print(ddd.keys())
print('Number of simulated events:', len(ddd['energy']))

n_samples = 1000
np.random.seed(90)
seed_1 = np.random.randint(1000, size=n_samples)
seed_2 = np.random.randint(1000, size=n_samples)
seed_3 = np.random.randint(1000, size=n_samples)
# Out:
# dict_keys(['dnn_axis', 'dnn_core', 'dnn_energy', 'dnn_xmax', 'event_id', 'auger_id', 'sd_id', 'is_saturated', 'core', 'axis', 'energy', 'xmax', 'element', 'mass', 'merit', 'fd_energy', 'fd_axis', 'sd_energy', 'sd_axis', 'sd_galactic_latitude', 'sd_galactic_longitude', 'sd_core', 'univ_energy', 'univ_axis', 'delta_mean_delta', 'delta_xmax', 'delta_energy', 'muon_number'])
# Number of simulated events: 443543

# %% [markdown]
# ## Data production cycle

# %%
# classes I need
mf = mass_fractions()
es = energy_spectrum()
smd = SMD_method()

# final results dictionary
final_results = {'iter': [], 'emin': [], 'light': [], 'heavy': [], 'frac_l': [], 'frac_h': []}

for k in range(n_samples):

    print('Iteration:', k+1, ' of ', n_samples)
    data_mask = flatten_distr(ddd['energy'], seed=seed_1[k])
    dd = dict_cutter(ddd, data_mask)

    print('After the first cut:', len(dd['energy']))

    # extract mass fractions
    mf.seed = seed_2[k]
    mass_mask = mf.extract_all_fractions(np.log10(dd['energy']*1e18), dd['mass'])
    dd = dict_cutter(dd, mass_mask)
    print('After mass fractions:', len(dd['energy']))

    # extract spectrum
    es.seed = seed_3[k]
    spectrum_mask = es.spectrum_fraction(dd['energy']*1e18)
    dd = dict_cutter(dd, spectrum_mask)
    print('After energy spectrum:', len(dd['energy']))

    # define charge
    dd['charge'] = np.empty_like(dd['mass'])
    for mass in names:
        dd['charge'][np.where(dd['mass']==names[mass])]=charges[mass]
    
    generate_xmax19(dd, 'dnn_xmax', 'energy')
    
    # estimate best quantiles
    thres_values = np.linspace(np.min(dd['xmax19']), np.max(dd['xmax19']), 27)
    res = { 'emin': [], 
            'light': [], 
            'heavy': [], 
            'N_light': [],
            'N_heavy': [],
            'N_tot': [],
            'SMD': [],
            }
    
    for ee in range(len(energies)-1):
        e_min = energies[ee]/1e18
        e_max =energies[ee+1]/1e18


        # extract energy range
        e_mask = (dd['energy']<e_max)&(dd['energy']>=e_min)
        data = dict_cutter(dd, e_mask)

        for i in range(1, len(thres_values) - 2):
            thres_h = thres_values[i]

            for j in range(i + 1, len(thres_values) - 1):

                thres_l = thres_values[j]
                mask_h = (data['xmax19']<thres_h)
                mask_l = (data['xmax19']>thres_l)
                light_frac = dict_cutter(data, mask_l)
                heavy_frac = dict_cutter(data, mask_h)

                value = smd.quantify_SMD(light_frac['energy'], light_frac['charge'], heavy_frac['energy'], heavy_frac['charge'], d_max=1)
                A_l = np.sum(np.log(light_frac['mass']))
                A_h = np.sum(np.log(heavy_frac['mass']))

                res['emin'].append(e_min)
                res['light'].append(thres_l)
                res['heavy'].append(thres_h)
                res['SMD'].append(value)
                res['N_light'].append(len(light_frac['xmax19']))
                res['N_heavy'].append(len(heavy_frac['xmax19']))
                res['N_tot'].append(len(data['xmax19']))

    for key, value in res.items():
        res[key] = np.array(value)

    # format final results
    for l in range(len(energies[:-1])):
        best_pos = np.where((res['SMD']==np.max(res['SMD'][res['emin']==energies[l]/1e18]))&(res['emin']==energies[l]/1e18))
        print(best_pos)
        frac_l = res['N_light'][best_pos]/res['N_tot'][best_pos]
        frac_h = res['N_heavy'][best_pos]/res['N_tot'][best_pos]

        final_results['iter'].append(k)
        final_results['emin'].append(energies[l]/1e18)
        final_results['light'].append(res['light'][best_pos])
        final_results['heavy'].append(res['heavy'][best_pos])
        final_results['frac_l'].append(frac_l)
        final_results['frac_h'].append(frac_h)


for key, value in final_results.items():
    final_results[key] = np.array(value)
display(final_results)
# Out:
# Iteration: 1  of  1000
# After the first cut: 369393
# After mass fractions: 108869
# After energy spectrum: 13601
# (array([114]),)
# (array([412]),)
# (array([692]),)
# (array([992]),)
# Iteration: 2  of  1000
# After the first cut: 369269
# After mass fractions: 109089
# After energy spectrum: 13773
# (array([93]),)
# (array([391]),)
# (array([671]),)
# (array([990]),)
# Iteration: 3  of  1000
# After the first cut: 369278
# After mass fractions: 108689
# After energy spectrum: 13671
# (array([70]),)
# (array([372]),)
# (array([649]),)
# (array([969]),)
# Iteration: 4  of  1000
# After the first cut: 369529
# After mass fractions: 109021
# After energy spectrum: 13709
# (array([92]),)
# (array([372]),)
# (array([672]),)
# (array([949]),)
# Iteration: 5  of  1000
# After the first cut: 369573
# After mass fractions: 108601
# After energy spectrum: 13694
# (array([94]),)
# (array([392]),)
# (array([672]),)
# (array([950]),)
# Iteration: 6  of  1000
# After the first cut: 369378
# After mass fractions: 108772
# After energy spectrum: 13678
# (array([71]),)
# (array([371]),)
# (array([649]),)
# (array([927]),)
# Iteration: 7  of  1000
# After the first cut: 369310
# After mass fractions: 108341
# After energy spectrum: 13604
# (array([92]),)
# (array([371]),)
# (array([671]),)
# (array([950]),)
# Iteration: 8  of  1000
# After the first cut: 369192
# After mass fractions: 108575
# After energy spectrum: 13724
# (array([92]),)
# (array([371]),)
# (array([690]),)
# (array([949]),)
# Iteration: 9  of  1000
# After the first cut: 369638
# After mass fractions: 108813
# After energy spectrum: 13773
# (array([93]),)
# (array([391]),)
# (array([671]),)
# (array([971]),)
# Iteration: 10  of  1000
# After the first cut: 369662
# After mass fractions: 108598
# After energy spectrum: 13605
# (array([93]),)
# (array([373]),)
# (array([670]),)
# (array([991]),)
# Iteration: 11  of  1000
# After the first cut: 369210
# After mass fractions: 108279
# After energy spectrum: 13569
# (array([73]),)
# (array([372]),)
# (array([670]),)
# (array([971]),)
# Iteration: 12  of  1000
# After the first cut: 369468
# After mass fractions: 109212
# After energy spectrum: 13994
# (array([72]),)
# (array([372]),)
# (array([670]),)
# (array([948]),)
# Iteration: 13  of  1000
# After the first cut: 369476
# After mass fractions: 108430
# After energy spectrum: 13739
# (array([72]),)
# (array([349]),)
# (array([670]),)
# (array([926]),)
# Iteration: 14  of  1000
# After the first cut: 369234
# After mass fractions: 108576
# After energy spectrum: 13881
# (array([93]),)
# (array([394]),)
# (array([693]),)
# (array([973]),)
# Iteration: 15  of  1000
# After the first cut: 369606
# After mass fractions: 108815
# After energy spectrum: 13943
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([948]),)
# Iteration: 16  of  1000
# After the first cut: 369169
# After mass fractions: 108950
# After energy spectrum: 13732
# (array([71]),)
# (array([371]),)
# (array([690]),)
# (array([990]),)
# Iteration: 17  of  1000
# After the first cut: 369662
# After mass fractions: 109082
# After energy spectrum: 13668
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([949]),)
# Iteration: 18  of  1000
# After the first cut: 369245
# After mass fractions: 108839
# After energy spectrum: 13730
# (array([93]),)
# (array([372]),)
# (array([672]),)
# (array([969]),)
# Iteration: 19  of  1000
# After the first cut: 369401
# After mass fractions: 109019
# After energy spectrum: 13724
# (array([93]),)
# (array([373]),)
# (array([691]),)
# (array([990]),)
# Iteration: 20  of  1000
# After the first cut: 369569
# After mass fractions: 108703
# After energy spectrum: 13729
# (array([94]),)
# (array([392]),)
# (array([692]),)
# (array([972]),)
# Iteration: 21  of  1000
# After the first cut: 369558
# After mass fractions: 108627
# After energy spectrum: 13751
# (array([72]),)
# (array([371]),)
# (array([669]),)
# (array([969]),)
# Iteration: 22  of  1000
# After the first cut: 369916
# After mass fractions: 109359
# After energy spectrum: 13899
# (array([93]),)
# (array([391]),)
# (array([671]),)
# (array([971]),)
# Iteration: 23  of  1000
# After the first cut: 370031
# After mass fractions: 108977
# After energy spectrum: 13658
# (array([94]),)
# (array([392]),)
# (array([672]),)
# (array([952]),)
# Iteration: 24  of  1000
# After the first cut: 369467
# After mass fractions: 108993
# After energy spectrum: 13718
# (array([93]),)
# (array([372]),)
# (array([671]),)
# (array([949]),)
# Iteration: 25  of  1000
# After the first cut: 369051
# After mass fractions: 108773
# After energy spectrum: 13753
# (array([72]),)
# (array([371]),)
# (array([672]),)
# (array([990]),)
# Iteration: 26  of  1000
# After the first cut: 369374
# After mass fractions: 108849
# After energy spectrum: 13629
# (array([72]),)
# (array([351]),)
# (array([670]),)
# (array([948]),)
# Iteration: 27  of  1000
# After the first cut: 369476
# After mass fractions: 108787
# After energy spectrum: 13613
# (array([73]),)
# (array([371]),)
# (array([669]),)
# (array([949]),)
# Iteration: 28  of  1000
# After the first cut: 369288
# After mass fractions: 108998
# After energy spectrum: 13605
# (array([74]),)
# (array([392]),)
# (array([671]),)
# (array([951]),)
# Iteration: 29  of  1000
# After the first cut: 369445
# After mass fractions: 108753
# After energy spectrum: 13758
# (array([72]),)
# (array([370]),)
# (array([671]),)
# (array([947]),)
# Iteration: 30  of  1000
# After the first cut: 369394
# After mass fractions: 108979
# After energy spectrum: 13703
# (array([73]),)
# (array([372]),)
# (array([670]),)
# (array([970]),)
# Iteration: 31  of  1000
# After the first cut: 369222
# After mass fractions: 108949
# After energy spectrum: 13812
# (array([93]),)
# (array([353]),)
# (array([670]),)
# (array([949]),)
# Iteration: 32  of  1000
# After the first cut: 369202
# After mass fractions: 108764
# After energy spectrum: 13733
# (array([94]),)
# (array([373]),)
# (array([690]),)
# (array([970]),)
# Iteration: 33  of  1000
# After the first cut: 369371
# After mass fractions: 108632
# After energy spectrum: 13627
# (array([73]),)
# (array([391]),)
# (array([671]),)
# (array([969]),)
# Iteration: 34  of  1000
# After the first cut: 369392
# After mass fractions: 108988
# After energy spectrum: 13595
# (array([93]),)
# (array([393]),)
# (array([691]),)
# (array([971]),)
# Iteration: 35  of  1000
# After the first cut: 369566
# After mass fractions: 108819
# After energy spectrum: 13691
# (array([74]),)
# (array([372]),)
# (array([690]),)
# (array([951]),)
# Iteration: 36  of  1000
# After the first cut: 369348
# After mass fractions: 108720
# After energy spectrum: 13754
# (array([72]),)
# (array([371]),)
# (array([691]),)
# (array([970]),)
# Iteration: 37  of  1000
# After the first cut: 368897
# After mass fractions: 109185
# After energy spectrum: 13641
# (array([72]),)
# (array([350]),)
# (array([669]),)
# (array([949]),)
# Iteration: 38  of  1000
# After the first cut: 369401
# After mass fractions: 108676
# After energy spectrum: 13649
# (array([72]),)
# (array([370]),)
# (array([649]),)
# (array([927]),)
# Iteration: 39  of  1000
# After the first cut: 369260
# After mass fractions: 108397
# After energy spectrum: 13717
# (array([92]),)
# (array([391]),)
# (array([672]),)
# (array([951]),)
# Iteration: 40  of  1000
# After the first cut: 369143
# After mass fractions: 108895
# After energy spectrum: 13864
# (array([72]),)
# (array([390]),)
# (array([671]),)
# (array([948]),)
# Iteration: 41  of  1000
# After the first cut: 369452
# After mass fractions: 108875
# After energy spectrum: 13884
# (array([74]),)
# (array([371]),)
# (array([671]),)
# (array([970]),)
# Iteration: 42  of  1000
# After the first cut: 369446
# After mass fractions: 108645
# After energy spectrum: 13614
# (array([73]),)
# (array([392]),)
# (array([671]),)
# (array([971]),)
# Iteration: 43  of  1000
# After the first cut: 369365
# After mass fractions: 108839
# After energy spectrum: 13640
# (array([73]),)
# (array([372]),)
# (array([671]),)
# (array([951]),)
# Iteration: 44  of  1000
# After the first cut: 369609
# After mass fractions: 108946
# After energy spectrum: 13862
# (array([93]),)
# (array([373]),)
# (array([692]),)
# (array([949]),)
# Iteration: 45  of  1000
# After the first cut: 369115
# After mass fractions: 108778
# After energy spectrum: 13706
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([970]),)
# Iteration: 46  of  1000
# After the first cut: 369056
# After mass fractions: 108419
# After energy spectrum: 13773
# (array([92]),)
# (array([372]),)
# (array([691]),)
# (array([969]),)
# Iteration: 47  of  1000
# After the first cut: 369620
# After mass fractions: 108788
# After energy spectrum: 13696
# (array([71]),)
# (array([370]),)
# (array([670]),)
# (array([925]),)
# Iteration: 48  of  1000
# After the first cut: 369096
# After mass fractions: 108729
# After energy spectrum: 13656
# (array([73]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 49  of  1000
# After the first cut: 369685
# After mass fractions: 109093
# After energy spectrum: 13702
# (array([51]),)
# (array([371]),)
# (array([670]),)
# (array([970]),)
# Iteration: 50  of  1000
# After the first cut: 369496
# After mass fractions: 108790
# After energy spectrum: 13683
# (array([93]),)
# (array([371]),)
# (array([670]),)
# (array([929]),)
# Iteration: 51  of  1000
# After the first cut: 369119
# After mass fractions: 108642
# After energy spectrum: 13728
# (array([93]),)
# (array([374]),)
# (array([672]),)
# (array([949]),)
# Iteration: 52  of  1000
# After the first cut: 369405
# After mass fractions: 109010
# After energy spectrum: 13613
# (array([72]),)
# (array([372]),)
# (array([670]),)
# (array([969]),)
# Iteration: 53  of  1000
# After the first cut: 369417
# After mass fractions: 108746
# After energy spectrum: 13761
# (array([71]),)
# (array([370]),)
# (array([669]),)
# (array([928]),)
# Iteration: 54  of  1000
# After the first cut: 369434
# After mass fractions: 108375
# After energy spectrum: 13362
# (array([73]),)
# (array([372]),)
# (array([671]),)
# (array([949]),)
# Iteration: 55  of  1000
# After the first cut: 369419
# After mass fractions: 108288
# After energy spectrum: 13598
# (array([72]),)
# (array([372]),)
# (array([670]),)
# (array([971]),)
# Iteration: 56  of  1000
# After the first cut: 369072
# After mass fractions: 108881
# After energy spectrum: 13850
# (array([73]),)
# (array([371]),)
# (array([651]),)
# (array([950]),)
# Iteration: 57  of  1000
# After the first cut: 369268
# After mass fractions: 108845
# After energy spectrum: 13894
# (array([92]),)
# (array([392]),)
# (array([691]),)
# (array([948]),)
# Iteration: 58  of  1000
# After the first cut: 369255
# After mass fractions: 108457
# After energy spectrum: 13559
# (array([74]),)
# (array([391]),)
# (array([692]),)
# (array([991]),)
# Iteration: 59  of  1000
# After the first cut: 369562
# After mass fractions: 108640
# After energy spectrum: 13792
# (array([93]),)
# (array([391]),)
# (array([691]),)
# (array([990]),)
# Iteration: 60  of  1000
# After the first cut: 369343
# After mass fractions: 108641
# After energy spectrum: 13554
# (array([73]),)
# (array([373]),)
# (array([650]),)
# (array([950]),)
# Iteration: 61  of  1000
# After the first cut: 369295
# After mass fractions: 108772
# After energy spectrum: 13575
# (array([73]),)
# (array([373]),)
# (array([691]),)
# (array([949]),)
# Iteration: 62  of  1000
# After the first cut: 369319
# After mass fractions: 108551
# After energy spectrum: 13454
# (array([71]),)
# (array([350]),)
# (array([669]),)
# (array([969]),)
# Iteration: 63  of  1000
# After the first cut: 369263
# After mass fractions: 109319
# After energy spectrum: 13791
# (array([71]),)
# (array([351]),)
# (array([649]),)
# (array([969]),)
# Iteration: 64  of  1000
# After the first cut: 369629
# After mass fractions: 108859
# After energy spectrum: 13780
# (array([111]),)
# (array([392]),)
# (array([692]),)
# (array([1010]),)
# Iteration: 65  of  1000
# After the first cut: 369620
# After mass fractions: 108658
# After energy spectrum: 13685
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([970]),)
# Iteration: 66  of  1000
# After the first cut: 369522
# After mass fractions: 108514
# After energy spectrum: 13724
# (array([50]),)
# (array([350]),)
# (array([670]),)
# (array([927]),)
# Iteration: 67  of  1000
# After the first cut: 369722
# After mass fractions: 108487
# After energy spectrum: 13677
# (array([93]),)
# (array([372]),)
# (array([672]),)
# (array([929]),)
# Iteration: 68  of  1000
# After the first cut: 369186
# After mass fractions: 108668
# After energy spectrum: 13783
# (array([94]),)
# (array([372]),)
# (array([672]),)
# (array([969]),)
# Iteration: 69  of  1000
# After the first cut: 369354
# After mass fractions: 108168
# After energy spectrum: 13503
# (array([71]),)
# (array([370]),)
# (array([670]),)
# (array([949]),)
# Iteration: 70  of  1000
# After the first cut: 369678
# After mass fractions: 108689
# After energy spectrum: 13641
# (array([71]),)
# (array([371]),)
# (array([649]),)
# (array([925]),)
# Iteration: 71  of  1000
# After the first cut: 369595
# After mass fractions: 108824
# After energy spectrum: 13828
# (array([92]),)
# (array([372]),)
# (array([671]),)
# (array([990]),)
# Iteration: 72  of  1000
# After the first cut: 369763
# After mass fractions: 108956
# After energy spectrum: 13700
# (array([93]),)
# (array([373]),)
# (array([670]),)
# (array([970]),)
# Iteration: 73  of  1000
# After the first cut: 369365
# After mass fractions: 108552
# After energy spectrum: 13674
# (array([72]),)
# (array([371]),)
# (array([650]),)
# (array([929]),)
# Iteration: 74  of  1000
# After the first cut: 369360
# After mass fractions: 109143
# After energy spectrum: 13744
# (array([73]),)
# (array([372]),)
# (array([692]),)
# (array([973]),)
# Iteration: 75  of  1000
# After the first cut: 369247
# After mass fractions: 108591
# After energy spectrum: 13724
# (array([71]),)
# (array([349]),)
# (array([650]),)
# (array([948]),)
# Iteration: 76  of  1000
# After the first cut: 369460
# After mass fractions: 108907
# After energy spectrum: 13855
# (array([93]),)
# (array([373]),)
# (array([692]),)
# (array([949]),)
# Iteration: 77  of  1000
# After the first cut: 369590
# After mass fractions: 108977
# After energy spectrum: 13808
# (array([94]),)
# (array([391]),)
# (array([692]),)
# (array([951]),)
# Iteration: 78  of  1000
# After the first cut: 369545
# After mass fractions: 108554
# After energy spectrum: 13885
# (array([92]),)
# (array([372]),)
# (array([650]),)
# (array([948]),)
# Iteration: 79  of  1000
# After the first cut: 368891
# After mass fractions: 108886
# After energy spectrum: 13763
# (array([72]),)
# (array([371]),)
# (array([650]),)
# (array([970]),)
# Iteration: 80  of  1000
# After the first cut: 369449
# After mass fractions: 108856
# After energy spectrum: 13710
# (array([73]),)
# (array([351]),)
# (array([650]),)
# (array([949]),)
# Iteration: 81  of  1000
# After the first cut: 369185
# After mass fractions: 109297
# After energy spectrum: 13784
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([971]),)
# Iteration: 82  of  1000
# After the first cut: 369152
# After mass fractions: 108672
# After energy spectrum: 13619
# (array([71]),)
# (array([350]),)
# (array([670]),)
# (array([947]),)
# Iteration: 83  of  1000
# After the first cut: 369398
# After mass fractions: 108747
# After energy spectrum: 13659
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([971]),)
# Iteration: 84  of  1000
# After the first cut: 369367
# After mass fractions: 108815
# After energy spectrum: 13804
# (array([70]),)
# (array([370]),)
# (array([650]),)
# (array([948]),)
# Iteration: 85  of  1000
# After the first cut: 369310
# After mass fractions: 108705
# After energy spectrum: 13812
# (array([93]),)
# (array([392]),)
# (array([710]),)
# (array([990]),)
# Iteration: 86  of  1000
# After the first cut: 369382
# After mass fractions: 108893
# After energy spectrum: 13717
# (array([72]),)
# (array([351]),)
# (array([669]),)
# (array([928]),)
# Iteration: 87  of  1000
# After the first cut: 369365
# After mass fractions: 108821
# After energy spectrum: 13687
# (array([92]),)
# (array([372]),)
# (array([652]),)
# (array([990]),)
# Iteration: 88  of  1000
# After the first cut: 369043
# After mass fractions: 108793
# After energy spectrum: 13629
# (array([72]),)
# (array([350]),)
# (array([650]),)
# (array([969]),)
# Iteration: 89  of  1000
# After the first cut: 369098
# After mass fractions: 108853
# After energy spectrum: 13587
# (array([94]),)
# (array([372]),)
# (array([690]),)
# (array([991]),)
# Iteration: 90  of  1000
# After the first cut: 369358
# After mass fractions: 108806
# After energy spectrum: 13669
# (array([93]),)
# (array([371]),)
# (array([692]),)
# (array([953]),)
# Iteration: 91  of  1000
# After the first cut: 369364
# After mass fractions: 108629
# After energy spectrum: 13680
# (array([73]),)
# (array([390]),)
# (array([692]),)
# (array([951]),)
# Iteration: 92  of  1000
# After the first cut: 369338
# After mass fractions: 109133
# After energy spectrum: 13782
# (array([74]),)
# (array([373]),)
# (array([671]),)
# (array([949]),)
# Iteration: 93  of  1000
# After the first cut: 369413
# After mass fractions: 109080
# After energy spectrum: 13844
# (array([92]),)
# (array([372]),)
# (array([692]),)
# (array([950]),)
# Iteration: 94  of  1000
# After the first cut: 369029
# After mass fractions: 108522
# After energy spectrum: 13750
# (array([72]),)
# (array([372]),)
# (array([651]),)
# (array([949]),)
# Iteration: 95  of  1000
# After the first cut: 369302
# After mass fractions: 108775
# After energy spectrum: 13881
# (array([95]),)
# (array([392]),)
# (array([691]),)
# (array([970]),)
# Iteration: 96  of  1000
# After the first cut: 369337
# After mass fractions: 108746
# After energy spectrum: 13816
# (array([92]),)
# (array([372]),)
# (array([691]),)
# (array([950]),)
# Iteration: 97  of  1000
# After the first cut: 369182
# After mass fractions: 108895
# After energy spectrum: 13891
# (array([93]),)
# (array([372]),)
# (array([691]),)
# (array([970]),)
# Iteration: 98  of  1000
# After the first cut: 369740
# After mass fractions: 108857
# After energy spectrum: 13755
# (array([73]),)
# (array([391]),)
# (array([690]),)
# (array([950]),)
# Iteration: 99  of  1000
# After the first cut: 369448
# After mass fractions: 108963
# After energy spectrum: 13868
# (array([73]),)
# (array([372]),)
# (array([670]),)
# (array([970]),)
# Iteration: 100  of  1000
# After the first cut: 369627
# After mass fractions: 108681
# After energy spectrum: 13599
# (array([72]),)
# (array([372]),)
# (array([690]),)
# (array([969]),)
# Iteration: 101  of  1000
# After the first cut: 369457
# After mass fractions: 108869
# After energy spectrum: 13848
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([950]),)
# Iteration: 102  of  1000
# After the first cut: 369294
# After mass fractions: 109001
# After energy spectrum: 13939
# (array([74]),)
# (array([393]),)
# (array([712]),)
# (array([929]),)
# Iteration: 103  of  1000
# After the first cut: 369503
# After mass fractions: 108770
# After energy spectrum: 13917
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([969]),)
# Iteration: 104  of  1000
# After the first cut: 369310
# After mass fractions: 108873
# After energy spectrum: 13796
# (array([74]),)
# (array([373]),)
# (array([671]),)
# (array([970]),)
# Iteration: 105  of  1000
# After the first cut: 369292
# After mass fractions: 109286
# After energy spectrum: 13761
# (array([94]),)
# (array([392]),)
# (array([691]),)
# (array([1011]),)
# Iteration: 106  of  1000
# After the first cut: 369841
# After mass fractions: 109162
# After energy spectrum: 13856
# (array([92]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 107  of  1000
# After the first cut: 369229
# After mass fractions: 109002
# After energy spectrum: 13689
# (array([74]),)
# (array([392]),)
# (array([691]),)
# (array([972]),)
# Iteration: 108  of  1000
# After the first cut: 369467
# After mass fractions: 108687
# After energy spectrum: 13934
# (array([93]),)
# (array([373]),)
# (array([691]),)
# (array([970]),)
# Iteration: 109  of  1000
# After the first cut: 369609
# After mass fractions: 109145
# After energy spectrum: 13626
# (array([73]),)
# (array([372]),)
# (array([691]),)
# (array([950]),)
# Iteration: 110  of  1000
# After the first cut: 369446
# After mass fractions: 108690
# After energy spectrum: 13682
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([951]),)
# Iteration: 111  of  1000
# After the first cut: 369763
# After mass fractions: 108909
# After energy spectrum: 13693
# (array([91]),)
# (array([372]),)
# (array([690]),)
# (array([950]),)
# Iteration: 112  of  1000
# After the first cut: 369667
# After mass fractions: 108945
# After energy spectrum: 13770
# (array([94]),)
# (array([371]),)
# (array([671]),)
# (array([990]),)
# Iteration: 113  of  1000
# After the first cut: 369393
# After mass fractions: 108850
# After energy spectrum: 13991
# (array([72]),)
# (array([373]),)
# (array([692]),)
# (array([971]),)
# Iteration: 114  of  1000
# After the first cut: 369770
# After mass fractions: 108921
# After energy spectrum: 13780
# (array([92]),)
# (array([371]),)
# (array([671]),)
# (array([952]),)
# Iteration: 115  of  1000
# After the first cut: 369020
# After mass fractions: 108366
# After energy spectrum: 13437
# (array([94]),)
# (array([391]),)
# (array([671]),)
# (array([1030]),)
# Iteration: 116  of  1000
# After the first cut: 369311
# After mass fractions: 108572
# After energy spectrum: 13718
# (array([73]),)
# (array([372]),)
# (array([691]),)
# (array([972]),)
# Iteration: 117  of  1000
# After the first cut: 369763
# After mass fractions: 108799
# After energy spectrum: 13636
# (array([71]),)
# (array([349]),)
# (array([671]),)
# (array([928]),)
# Iteration: 118  of  1000
# After the first cut: 369242
# After mass fractions: 108363
# After energy spectrum: 13553
# (array([71]),)
# (array([371]),)
# (array([690]),)
# (array([952]),)
# Iteration: 119  of  1000
# After the first cut: 369401
# After mass fractions: 108344
# After energy spectrum: 13825
# (array([71]),)
# (array([351]),)
# (array([670]),)
# (array([971]),)
# Iteration: 120  of  1000
# After the first cut: 369293
# After mass fractions: 108825
# After energy spectrum: 13824
# (array([95]),)
# (array([392]),)
# (array([690]),)
# (array([950]),)
# Iteration: 121  of  1000
# After the first cut: 369212
# After mass fractions: 108777
# After energy spectrum: 13752
# (array([51]),)
# (array([352]),)
# (array([650]),)
# (array([949]),)
# Iteration: 122  of  1000
# After the first cut: 369401
# After mass fractions: 108589
# After energy spectrum: 13708
# (array([73]),)
# (array([372]),)
# (array([650]),)
# (array([970]),)
# Iteration: 123  of  1000
# After the first cut: 369031
# After mass fractions: 108478
# After energy spectrum: 13681
# (array([73]),)
# (array([373]),)
# (array([670]),)
# (array([969]),)
# Iteration: 124  of  1000
# After the first cut: 369409
# After mass fractions: 108868
# After energy spectrum: 13813
# (array([94]),)
# (array([372]),)
# (array([693]),)
# (array([952]),)
# Iteration: 125  of  1000
# After the first cut: 369411
# After mass fractions: 108828
# After energy spectrum: 13694
# (array([73]),)
# (array([371]),)
# (array([690]),)
# (array([951]),)
# Iteration: 126  of  1000
# After the first cut: 369416
# After mass fractions: 108413
# After energy spectrum: 13685
# (array([92]),)
# (array([372]),)
# (array([650]),)
# (array([970]),)
# Iteration: 127  of  1000
# After the first cut: 369435
# After mass fractions: 109349
# After energy spectrum: 13911
# (array([93]),)
# (array([371]),)
# (array([671]),)
# (array([969]),)
# Iteration: 128  of  1000
# After the first cut: 369267
# After mass fractions: 108672
# After energy spectrum: 13837
# (array([73]),)
# (array([372]),)
# (array([671]),)
# (array([948]),)
# Iteration: 129  of  1000
# After the first cut: 369458
# After mass fractions: 108600
# After energy spectrum: 13795
# (array([74]),)
# (array([392]),)
# (array([672]),)
# (array([952]),)
# Iteration: 130  of  1000
# After the first cut: 369448
# After mass fractions: 108588
# After energy spectrum: 13477
# (array([70]),)
# (array([370]),)
# (array([669]),)
# (array([926]),)
# Iteration: 131  of  1000
# After the first cut: 369813
# After mass fractions: 108978
# After energy spectrum: 13879
# (array([92]),)
# (array([372]),)
# (array([691]),)
# (array([969]),)
# Iteration: 132  of  1000
# After the first cut: 369569
# After mass fractions: 108894
# After energy spectrum: 13685
# (array([92]),)
# (array([391]),)
# (array([670]),)
# (array([971]),)
# Iteration: 133  of  1000
# After the first cut: 369230
# After mass fractions: 108677
# After energy spectrum: 13601
# (array([73]),)
# (array([372]),)
# (array([691]),)
# (array([969]),)
# Iteration: 134  of  1000
# After the first cut: 369180
# After mass fractions: 108770
# After energy spectrum: 13432
# (array([72]),)
# (array([373]),)
# (array([672]),)
# (array([971]),)
# Iteration: 135  of  1000
# After the first cut: 369246
# After mass fractions: 108941
# After energy spectrum: 13666
# (array([92]),)
# (array([370]),)
# (array([691]),)
# (array([969]),)
# Iteration: 136  of  1000
# After the first cut: 369408
# After mass fractions: 108789
# After energy spectrum: 13799
# (array([71]),)
# (array([350]),)
# (array([671]),)
# (array([948]),)
# Iteration: 137  of  1000
# After the first cut: 368999
# After mass fractions: 108675
# After energy spectrum: 13718
# (array([94]),)
# (array([371]),)
# (array([672]),)
# (array([928]),)
# Iteration: 138  of  1000
# After the first cut: 369432
# After mass fractions: 108752
# After energy spectrum: 13661
# (array([72]),)
# (array([371]),)
# (array([650]),)
# (array([970]),)
# Iteration: 139  of  1000
# After the first cut: 369513
# After mass fractions: 108684
# After energy spectrum: 13823
# (array([71]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 140  of  1000
# After the first cut: 369251
# After mass fractions: 108686
# After energy spectrum: 13686
# (array([71]),)
# (array([370]),)
# (array([669]),)
# (array([927]),)
# Iteration: 141  of  1000
# After the first cut: 369191
# After mass fractions: 108889
# After energy spectrum: 13865
# (array([74]),)
# (array([373]),)
# (array([670]),)
# (array([951]),)
# Iteration: 142  of  1000
# After the first cut: 369685
# After mass fractions: 108750
# After energy spectrum: 13754
# (array([73]),)
# (array([372]),)
# (array([649]),)
# (array([970]),)
# Iteration: 143  of  1000
# After the first cut: 369233
# After mass fractions: 108825
# After energy spectrum: 13706
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([950]),)
# Iteration: 144  of  1000
# After the first cut: 369069
# After mass fractions: 108953
# After energy spectrum: 13633
# (array([71]),)
# (array([370]),)
# (array([649]),)
# (array([948]),)
# Iteration: 145  of  1000
# After the first cut: 369317
# After mass fractions: 108689
# After energy spectrum: 13727
# (array([73]),)
# (array([371]),)
# (array([670]),)
# (array([970]),)
# Iteration: 146  of  1000
# After the first cut: 369256
# After mass fractions: 108821
# After energy spectrum: 13795
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([948]),)
# Iteration: 147  of  1000
# After the first cut: 369354
# After mass fractions: 108607
# After energy spectrum: 13689
# (array([93]),)
# (array([392]),)
# (array([671]),)
# (array([971]),)
# Iteration: 148  of  1000
# After the first cut: 369493
# After mass fractions: 108912
# After energy spectrum: 13565
# (array([72]),)
# (array([350]),)
# (array([650]),)
# (array([948]),)
# Iteration: 149  of  1000
# After the first cut: 369785
# After mass fractions: 109299
# After energy spectrum: 13842
# (array([71]),)
# (array([370]),)
# (array([669]),)
# (array([927]),)
# Iteration: 150  of  1000
# After the first cut: 369124
# After mass fractions: 108641
# After energy spectrum: 13750
# (array([93]),)
# (array([392]),)
# (array([673]),)
# (array([949]),)
# Iteration: 151  of  1000
# After the first cut: 369376
# After mass fractions: 109180
# After energy spectrum: 13704
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([947]),)
# Iteration: 152  of  1000
# After the first cut: 369587
# After mass fractions: 109048
# After energy spectrum: 13863
# (array([94]),)
# (array([391]),)
# (array([690]),)
# (array([971]),)
# Iteration: 153  of  1000
# After the first cut: 369510
# After mass fractions: 108572
# After energy spectrum: 13721
# (array([71]),)
# (array([371]),)
# (array([670]),)
# (array([969]),)
# Iteration: 154  of  1000
# After the first cut: 369314
# After mass fractions: 108492
# After energy spectrum: 13851
# (array([73]),)
# (array([371]),)
# (array([671]),)
# (array([951]),)
# Iteration: 155  of  1000
# After the first cut: 369547
# After mass fractions: 109063
# After energy spectrum: 13760
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([972]),)
# Iteration: 156  of  1000
# After the first cut: 369803
# After mass fractions: 108397
# After energy spectrum: 13711
# (array([93]),)
# (array([392]),)
# (array([693]),)
# (array([969]),)
# Iteration: 157  of  1000
# After the first cut: 369417
# After mass fractions: 108752
# After energy spectrum: 13832
# (array([92]),)
# (array([372]),)
# (array([691]),)
# (array([950]),)
# Iteration: 158  of  1000
# After the first cut: 369366
# After mass fractions: 108743
# After energy spectrum: 13652
# (array([72]),)
# (array([371]),)
# (array([690]),)
# (array([949]),)
# Iteration: 159  of  1000
# After the first cut: 369136
# After mass fractions: 109000
# After energy spectrum: 13609
# (array([92]),)
# (array([373]),)
# (array([691]),)
# (array([948]),)
# Iteration: 160  of  1000
# After the first cut: 368915
# After mass fractions: 108430
# After energy spectrum: 13757
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([948]),)
# Iteration: 161  of  1000
# After the first cut: 369641
# After mass fractions: 108865
# After energy spectrum: 13855
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([992]),)
# Iteration: 162  of  1000
# After the first cut: 369416
# After mass fractions: 108626
# After energy spectrum: 13596
# (array([71]),)
# (array([349]),)
# (array([648]),)
# (array([949]),)
# Iteration: 163  of  1000
# After the first cut: 369244
# After mass fractions: 108418
# After energy spectrum: 13679
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([972]),)
# Iteration: 164  of  1000
# After the first cut: 369374
# After mass fractions: 108798
# After energy spectrum: 13680
# (array([73]),)
# (array([349]),)
# (array([669]),)
# (array([949]),)
# Iteration: 165  of  1000
# After the first cut: 369293
# After mass fractions: 108826
# After energy spectrum: 13847
# (array([92]),)
# (array([371]),)
# (array([671]),)
# (array([951]),)
# Iteration: 166  of  1000
# After the first cut: 369451
# After mass fractions: 109000
# After energy spectrum: 13705
# (array([95]),)
# (array([392]),)
# (array([672]),)
# (array([990]),)
# Iteration: 167  of  1000
# After the first cut: 369621
# After mass fractions: 108652
# After energy spectrum: 13636
# (array([94]),)
# (array([373]),)
# (array([692]),)
# (array([990]),)
# Iteration: 168  of  1000
# After the first cut: 369434
# After mass fractions: 109091
# After energy spectrum: 13659
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([947]),)
# Iteration: 169  of  1000
# After the first cut: 369086
# After mass fractions: 108754
# After energy spectrum: 13793
# (array([92]),)
# (array([372]),)
# (array([710]),)
# (array([950]),)
# Iteration: 170  of  1000
# After the first cut: 369413
# After mass fractions: 108675
# After energy spectrum: 13839
# (array([93]),)
# (array([393]),)
# (array([711]),)
# (array([949]),)
# Iteration: 171  of  1000
# After the first cut: 369283
# After mass fractions: 108791
# After energy spectrum: 13598
# (array([72]),)
# (array([371]),)
# (array([691]),)
# (array([949]),)
# Iteration: 172  of  1000
# After the first cut: 369245
# After mass fractions: 108653
# After energy spectrum: 13689
# (array([71]),)
# (array([370]),)
# (array([671]),)
# (array([949]),)
# Iteration: 173  of  1000
# After the first cut: 368967
# After mass fractions: 108529
# After energy spectrum: 13645
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([951]),)
# Iteration: 174  of  1000
# After the first cut: 369638
# After mass fractions: 108715
# After energy spectrum: 13769
# (array([71]),)
# (array([371]),)
# (array([649]),)
# (array([947]),)
# Iteration: 175  of  1000
# After the first cut: 369763
# After mass fractions: 108838
# After energy spectrum: 13571
# (array([111]),)
# (array([392]),)
# (array([691]),)
# (array([990]),)
# Iteration: 176  of  1000
# After the first cut: 369726
# After mass fractions: 109374
# After energy spectrum: 14015
# (array([92]),)
# (array([371]),)
# (array([672]),)
# (array([952]),)
# Iteration: 177  of  1000
# After the first cut: 369916
# After mass fractions: 108967
# After energy spectrum: 13851
# (array([93]),)
# (array([372]),)
# (array([692]),)
# (array([928]),)
# Iteration: 178  of  1000
# After the first cut: 369035
# After mass fractions: 108771
# After energy spectrum: 13643
# (array([92]),)
# (array([372]),)
# (array([671]),)
# (array([969]),)
# Iteration: 179  of  1000
# After the first cut: 369681
# After mass fractions: 108668
# After energy spectrum: 13654
# (array([93]),)
# (array([372]),)
# (array([652]),)
# (array([951]),)
# Iteration: 180  of  1000
# After the first cut: 369419
# After mass fractions: 109332
# After energy spectrum: 13938
# (array([93]),)
# (array([393]),)
# (array([670]),)
# (array([973]),)
# Iteration: 181  of  1000
# After the first cut: 369379
# After mass fractions: 109088
# After energy spectrum: 13811
# (array([92]),)
# (array([392]),)
# (array([690]),)
# (array([970]),)
# Iteration: 182  of  1000
# After the first cut: 369559
# After mass fractions: 109378
# After energy spectrum: 13842
# (array([73]),)
# (array([371]),)
# (array([669]),)
# (array([949]),)
# Iteration: 183  of  1000
# After the first cut: 369434
# After mass fractions: 108964
# After energy spectrum: 13792
# (array([71]),)
# (array([370]),)
# (array([648]),)
# (array([948]),)
# Iteration: 184  of  1000
# After the first cut: 369576
# After mass fractions: 108901
# After energy spectrum: 13834
# (array([93]),)
# (array([391]),)
# (array([672]),)
# (array([971]),)
# Iteration: 185  of  1000
# After the first cut: 369132
# After mass fractions: 108754
# After energy spectrum: 13888
# (array([72]),)
# (array([370]),)
# (array([671]),)
# (array([926]),)
# Iteration: 186  of  1000
# After the first cut: 369374
# After mass fractions: 108840
# After energy spectrum: 13686
# (array([93]),)
# (array([372]),)
# (array([671]),)
# (array([951]),)
# Iteration: 187  of  1000
# After the first cut: 369756
# After mass fractions: 108846
# After energy spectrum: 13717
# (array([71]),)
# (array([348]),)
# (array([669]),)
# (array([926]),)
# Iteration: 188  of  1000
# After the first cut: 368989
# After mass fractions: 108439
# After energy spectrum: 13616
# (array([72]),)
# (array([370]),)
# (array([671]),)
# (array([990]),)
# Iteration: 189  of  1000
# After the first cut: 370090
# After mass fractions: 108996
# After energy spectrum: 13944
# (array([94]),)
# (array([392]),)
# (array([691]),)
# (array([1010]),)
# Iteration: 190  of  1000
# After the first cut: 369704
# After mass fractions: 109234
# After energy spectrum: 13788
# (array([72]),)
# (array([371]),)
# (array([651]),)
# (array([990]),)
# Iteration: 191  of  1000
# After the first cut: 369656
# After mass fractions: 108859
# After energy spectrum: 13623
# (array([92]),)
# (array([372]),)
# (array([692]),)
# (array([929]),)
# Iteration: 192  of  1000
# After the first cut: 369295
# After mass fractions: 108705
# After energy spectrum: 13594
# (array([92]),)
# (array([392]),)
# (array([692]),)
# (array([1010]),)
# Iteration: 193  of  1000
# After the first cut: 369194
# After mass fractions: 109041
# After energy spectrum: 13734
# (array([92]),)
# (array([373]),)
# (array([671]),)
# (array([992]),)
# Iteration: 194  of  1000
# After the first cut: 369413
# After mass fractions: 108986
# After energy spectrum: 13734
# (array([93]),)
# (array([393]),)
# (array([672]),)
# (array([971]),)
# Iteration: 195  of  1000
# After the first cut: 369488
# After mass fractions: 109105
# After energy spectrum: 13822
# (array([92]),)
# (array([392]),)
# (array([692]),)
# (array([949]),)
# Iteration: 196  of  1000
# After the first cut: 369508
# After mass fractions: 108863
# After energy spectrum: 13727
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([990]),)
# Iteration: 197  of  1000
# After the first cut: 369596
# After mass fractions: 108575
# After energy spectrum: 13640
# (array([72]),)
# (array([371]),)
# (array([669]),)
# (array([950]),)
# Iteration: 198  of  1000
# After the first cut: 369332
# After mass fractions: 108572
# After energy spectrum: 13818
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([926]),)
# Iteration: 199  of  1000
# After the first cut: 369329
# After mass fractions: 108273
# After energy spectrum: 13813
# (array([73]),)
# (array([371]),)
# (array([650]),)
# (array([971]),)
# Iteration: 200  of  1000
# After the first cut: 369650
# After mass fractions: 108768
# After energy spectrum: 13602
# (array([74]),)
# (array([372]),)
# (array([672]),)
# (array([970]),)
# Iteration: 201  of  1000
# After the first cut: 369446
# After mass fractions: 108382
# After energy spectrum: 13760
# (array([71]),)
# (array([350]),)
# (array([670]),)
# (array([949]),)
# Iteration: 202  of  1000
# After the first cut: 369051
# After mass fractions: 108520
# After energy spectrum: 13640
# (array([75]),)
# (array([391]),)
# (array([672]),)
# (array([970]),)
# Iteration: 203  of  1000
# After the first cut: 369279
# After mass fractions: 108831
# After energy spectrum: 13799
# (array([73]),)
# (array([372]),)
# (array([692]),)
# (array([969]),)
# Iteration: 204  of  1000
# After the first cut: 369631
# After mass fractions: 108994
# After energy spectrum: 13916
# (array([72]),)
# (array([370]),)
# (array([648]),)
# (array([969]),)
# Iteration: 205  of  1000
# After the first cut: 369481
# After mass fractions: 109188
# After energy spectrum: 13841
# (array([93]),)
# (array([391]),)
# (array([692]),)
# (array([1011]),)
# Iteration: 206  of  1000
# After the first cut: 369364
# After mass fractions: 109057
# After energy spectrum: 13762
# (array([71]),)
# (array([351]),)
# (array([650]),)
# (array([948]),)
# Iteration: 207  of  1000
# After the first cut: 369409
# After mass fractions: 108931
# After energy spectrum: 13690
# (array([73]),)
# (array([372]),)
# (array([691]),)
# (array([990]),)
# Iteration: 208  of  1000
# After the first cut: 369529
# After mass fractions: 108544
# After energy spectrum: 13604
# (array([92]),)
# (array([372]),)
# (array([670]),)
# (array([969]),)
# Iteration: 209  of  1000
# After the first cut: 369430
# After mass fractions: 108862
# After energy spectrum: 13699
# (array([72]),)
# (array([371]),)
# (array([690]),)
# (array([948]),)
# Iteration: 210  of  1000
# After the first cut: 369662
# After mass fractions: 109035
# After energy spectrum: 13687
# (array([72]),)
# (array([373]),)
# (array([670]),)
# (array([969]),)
# Iteration: 211  of  1000
# After the first cut: 369109
# After mass fractions: 108509
# After energy spectrum: 13605
# (array([93]),)
# (array([391]),)
# (array([673]),)
# (array([972]),)
# Iteration: 212  of  1000
# After the first cut: 369370
# After mass fractions: 108385
# After energy spectrum: 13685
# (array([93]),)
# (array([374]),)
# (array([691]),)
# (array([992]),)
# Iteration: 213  of  1000
# After the first cut: 369283
# After mass fractions: 108950
# After energy spectrum: 13725
# (array([72]),)
# (array([371]),)
# (array([649]),)
# (array([969]),)
# Iteration: 214  of  1000
# After the first cut: 369449
# After mass fractions: 108804
# After energy spectrum: 13632
# (array([74]),)
# (array([371]),)
# (array([670]),)
# (array([969]),)
# Iteration: 215  of  1000
# After the first cut: 369665
# After mass fractions: 109017
# After energy spectrum: 13847
# (array([51]),)
# (array([371]),)
# (array([690]),)
# (array([950]),)
# Iteration: 216  of  1000
# After the first cut: 369654
# After mass fractions: 108982
# After energy spectrum: 13758
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([970]),)
# Iteration: 217  of  1000
# After the first cut: 369677
# After mass fractions: 109112
# After energy spectrum: 13828
# (array([72]),)
# (array([370]),)
# (array([671]),)
# (array([970]),)
# Iteration: 218  of  1000
# After the first cut: 369193
# After mass fractions: 108213
# After energy spectrum: 13559
# (array([73]),)
# (array([391]),)
# (array([670]),)
# (array([950]),)
# Iteration: 219  of  1000
# After the first cut: 369581
# After mass fractions: 109040
# After energy spectrum: 13506
# (array([94]),)
# (array([393]),)
# (array([692]),)
# (array([970]),)
# Iteration: 220  of  1000
# After the first cut: 369292
# After mass fractions: 108834
# After energy spectrum: 13776
# (array([93]),)
# (array([372]),)
# (array([671]),)
# (array([971]),)
# Iteration: 221  of  1000
# After the first cut: 369398
# After mass fractions: 108895
# After energy spectrum: 13720
# (array([94]),)
# (array([392]),)
# (array([671]),)
# (array([951]),)
# Iteration: 222  of  1000
# After the first cut: 369404
# After mass fractions: 108704
# After energy spectrum: 13812
# (array([93]),)
# (array([393]),)
# (array([691]),)
# (array([990]),)
# Iteration: 223  of  1000
# After the first cut: 369344
# After mass fractions: 109142
# After energy spectrum: 13682
# (array([71]),)
# (array([369]),)
# (array([648]),)
# (array([925]),)
# Iteration: 224  of  1000
# After the first cut: 369491
# After mass fractions: 108922
# After energy spectrum: 13611
# (array([92]),)
# (array([373]),)
# (array([691]),)
# (array([971]),)
# Iteration: 225  of  1000
# After the first cut: 369637
# After mass fractions: 108815
# After energy spectrum: 13764
# (array([93]),)
# (array([392]),)
# (array([671]),)
# (array([949]),)
# Iteration: 226  of  1000
# After the first cut: 369376
# After mass fractions: 109124
# After energy spectrum: 13641
# (array([73]),)
# (array([370]),)
# (array([670]),)
# (array([990]),)
# Iteration: 227  of  1000
# After the first cut: 369916
# After mass fractions: 108894
# After energy spectrum: 13739
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([948]),)
# Iteration: 228  of  1000
# After the first cut: 369399
# After mass fractions: 108503
# After energy spectrum: 13687
# (array([73]),)
# (array([371]),)
# (array([650]),)
# (array([969]),)
# Iteration: 229  of  1000
# After the first cut: 369374
# After mass fractions: 108855
# After energy spectrum: 13598
# (array([92]),)
# (array([372]),)
# (array([650]),)
# (array([972]),)
# Iteration: 230  of  1000
# After the first cut: 369242
# After mass fractions: 108974
# After energy spectrum: 13762
# (array([51]),)
# (array([350]),)
# (array([670]),)
# (array([948]),)
# Iteration: 231  of  1000
# After the first cut: 369221
# After mass fractions: 109028
# After energy spectrum: 13712
# (array([92]),)
# (array([373]),)
# (array([671]),)
# (array([974]),)
# Iteration: 232  of  1000
# After the first cut: 369474
# After mass fractions: 108478
# After energy spectrum: 13628
# (array([73]),)
# (array([371]),)
# (array([691]),)
# (array([969]),)
# Iteration: 233  of  1000
# After the first cut: 369374
# After mass fractions: 108521
# After energy spectrum: 13609
# (array([73]),)
# (array([372]),)
# (array([670]),)
# (array([970]),)
# Iteration: 234  of  1000
# After the first cut: 369408
# After mass fractions: 108710
# After energy spectrum: 13600
# (array([93]),)
# (array([371]),)
# (array([669]),)
# (array([971]),)
# Iteration: 235  of  1000
# After the first cut: 369507
# After mass fractions: 109103
# After energy spectrum: 13777
# (array([71]),)
# (array([370]),)
# (array([650]),)
# (array([948]),)
# Iteration: 236  of  1000
# After the first cut: 369245
# After mass fractions: 108902
# After energy spectrum: 13646
# (array([72]),)
# (array([391]),)
# (array([692]),)
# (array([970]),)
# Iteration: 237  of  1000
# After the first cut: 369478
# After mass fractions: 108775
# After energy spectrum: 13647
# (array([92]),)
# (array([392]),)
# (array([670]),)
# (array([950]),)
# Iteration: 238  of  1000
# After the first cut: 369374
# After mass fractions: 108754
# After energy spectrum: 13566
# (array([72]),)
# (array([370]),)
# (array([650]),)
# (array([928]),)
# Iteration: 239  of  1000
# After the first cut: 369608
# After mass fractions: 108846
# After energy spectrum: 13681
# (array([73]),)
# (array([373]),)
# (array([672]),)
# (array([991]),)
# Iteration: 240  of  1000
# After the first cut: 369841
# After mass fractions: 109121
# After energy spectrum: 13995
# (array([93]),)
# (array([374]),)
# (array([694]),)
# (array([969]),)
# Iteration: 241  of  1000
# After the first cut: 369480
# After mass fractions: 108530
# After energy spectrum: 13876
# (array([95]),)
# (array([392]),)
# (array([692]),)
# (array([952]),)
# Iteration: 242  of  1000
# After the first cut: 369534
# After mass fractions: 108633
# After energy spectrum: 13678
# (array([72]),)
# (array([390]),)
# (array([650]),)
# (array([948]),)
# Iteration: 243  of  1000
# After the first cut: 369452
# After mass fractions: 108640
# After energy spectrum: 13741
# (array([72]),)
# (array([351]),)
# (array([670]),)
# (array([951]),)
# Iteration: 244  of  1000
# After the first cut: 369375
# After mass fractions: 109137
# After energy spectrum: 13630
# (array([94]),)
# (array([392]),)
# (array([671]),)
# (array([950]),)
# Iteration: 245  of  1000
# After the first cut: 369510
# After mass fractions: 108754
# After energy spectrum: 13849
# (array([51]),)
# (array([370]),)
# (array([670]),)
# (array([948]),)
# Iteration: 246  of  1000
# After the first cut: 369430
# After mass fractions: 108993
# After energy spectrum: 13921
# (array([94]),)
# (array([371]),)
# (array([691]),)
# (array([930]),)
# Iteration: 247  of  1000
# After the first cut: 369613
# After mass fractions: 108640
# After energy spectrum: 13843
# (array([73]),)
# (array([351]),)
# (array([671]),)
# (array([927]),)
# Iteration: 248  of  1000
# After the first cut: 369260
# After mass fractions: 108763
# After energy spectrum: 13625
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([993]),)
# Iteration: 249  of  1000
# After the first cut: 369597
# After mass fractions: 108649
# After energy spectrum: 13779
# (array([73]),)
# (array([371]),)
# (array([671]),)
# (array([930]),)
# Iteration: 250  of  1000
# After the first cut: 369771
# After mass fractions: 109239
# After energy spectrum: 13873
# (array([92]),)
# (array([372]),)
# (array([690]),)
# (array([950]),)
# Iteration: 251  of  1000
# After the first cut: 369518
# After mass fractions: 108870
# After energy spectrum: 13673
# (array([93]),)
# (array([372]),)
# (array([691]),)
# (array([970]),)
# Iteration: 252  of  1000
# After the first cut: 369562
# After mass fractions: 109251
# After energy spectrum: 13837
# (array([71]),)
# (array([372]),)
# (array([650]),)
# (array([928]),)
# Iteration: 253  of  1000
# After the first cut: 369818
# After mass fractions: 108550
# After energy spectrum: 13707
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([926]),)
# Iteration: 254  of  1000
# After the first cut: 369695
# After mass fractions: 108888
# After energy spectrum: 13917
# (array([72]),)
# (array([371]),)
# (array([650]),)
# (array([926]),)
# Iteration: 255  of  1000
# After the first cut: 369437
# After mass fractions: 108722
# After energy spectrum: 13801
# (array([51]),)
# (array([369]),)
# (array([670]),)
# (array([948]),)
# Iteration: 256  of  1000
# After the first cut: 369841
# After mass fractions: 109002
# After energy spectrum: 13774
# (array([74]),)
# (array([372]),)
# (array([671]),)
# (array([970]),)
# Iteration: 257  of  1000
# After the first cut: 369702
# After mass fractions: 108661
# After energy spectrum: 13772
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([970]),)
# Iteration: 258  of  1000
# After the first cut: 369560
# After mass fractions: 108900
# After energy spectrum: 13646
# (array([70]),)
# (array([370]),)
# (array([650]),)
# (array([947]),)
# Iteration: 259  of  1000
# After the first cut: 369411
# After mass fractions: 108324
# After energy spectrum: 13612
# (array([73]),)
# (array([372]),)
# (array([670]),)
# (array([949]),)
# Iteration: 260  of  1000
# After the first cut: 369482
# After mass fractions: 108893
# After energy spectrum: 13977
# (array([93]),)
# (array([392]),)
# (array([692]),)
# (array([991]),)
# Iteration: 261  of  1000
# After the first cut: 369370
# After mass fractions: 109120
# After energy spectrum: 14028
# (array([73]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 262  of  1000
# After the first cut: 369630
# After mass fractions: 109194
# After energy spectrum: 13883
# (array([93]),)
# (array([392]),)
# (array([671]),)
# (array([971]),)
# Iteration: 263  of  1000
# After the first cut: 369424
# After mass fractions: 108823
# After energy spectrum: 13726
# (array([94]),)
# (array([392]),)
# (array([672]),)
# (array([969]),)
# Iteration: 264  of  1000
# After the first cut: 369163
# After mass fractions: 108641
# After energy spectrum: 13671
# (array([92]),)
# (array([373]),)
# (array([671]),)
# (array([990]),)
# Iteration: 265  of  1000
# After the first cut: 369025
# After mass fractions: 108868
# After energy spectrum: 13898
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([951]),)
# Iteration: 266  of  1000
# After the first cut: 369367
# After mass fractions: 108578
# After energy spectrum: 13776
# (array([92]),)
# (array([373]),)
# (array([690]),)
# (array([970]),)
# Iteration: 267  of  1000
# After the first cut: 369143
# After mass fractions: 108739
# After energy spectrum: 13704
# (array([71]),)
# (array([372]),)
# (array([670]),)
# (array([950]),)
# Iteration: 268  of  1000
# After the first cut: 369417
# After mass fractions: 108686
# After energy spectrum: 13627
# (array([71]),)
# (array([351]),)
# (array([649]),)
# (array([969]),)
# Iteration: 269  of  1000
# After the first cut: 369345
# After mass fractions: 108564
# After energy spectrum: 13498
# (array([74]),)
# (array([372]),)
# (array([691]),)
# (array([949]),)
# Iteration: 270  of  1000
# After the first cut: 369440
# After mass fractions: 109058
# After energy spectrum: 13883
# (array([92]),)
# (array([393]),)
# (array([692]),)
# (array([969]),)
# Iteration: 271  of  1000
# After the first cut: 369549
# After mass fractions: 109021
# After energy spectrum: 13702
# (array([71]),)
# (array([350]),)
# (array([648]),)
# (array([950]),)
# Iteration: 272  of  1000
# After the first cut: 369385
# After mass fractions: 108656
# After energy spectrum: 13642
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([949]),)
# Iteration: 273  of  1000
# After the first cut: 369262
# After mass fractions: 108631
# After energy spectrum: 13680
# (array([93]),)
# (array([391]),)
# (array([672]),)
# (array([949]),)
# Iteration: 274  of  1000
# After the first cut: 369139
# After mass fractions: 108804
# After energy spectrum: 13785
# (array([92]),)
# (array([373]),)
# (array([650]),)
# (array([972]),)
# Iteration: 275  of  1000
# After the first cut: 369772
# After mass fractions: 108966
# After energy spectrum: 13723
# (array([92]),)
# (array([372]),)
# (array([690]),)
# (array([949]),)
# Iteration: 276  of  1000
# After the first cut: 369185
# After mass fractions: 108772
# After energy spectrum: 13692
# (array([71]),)
# (array([350]),)
# (array([649]),)
# (array([928]),)
# Iteration: 277  of  1000
# After the first cut: 369427
# ...
# After the first cut: 369562
# After mass fractions: 108814
# After energy spectrum: 13646
# (array([94]),)
# (array([371]),)
# (array([649]),)
# (array([970]),)
# Iteration: 913  of  1000
# After the first cut: 369702
# After mass fractions: 109068
# After energy spectrum: 13741
# (array([93]),)
# (array([394]),)
# (array([691]),)
# (array([971]),)
# Iteration: 914  of  1000
# After the first cut: 369860
# After mass fractions: 109007
# After energy spectrum: 13615
# (array([93]),)
# (array([392]),)
# (array([671]),)
# (array([971]),)
# Iteration: 915  of  1000
# After the first cut: 368992
# After mass fractions: 108899
# After energy spectrum: 13729
# (array([93]),)
# (array([391]),)
# (array([691]),)
# (array([951]),)
# Iteration: 916  of  1000
# After the first cut: 369367
# After mass fractions: 108633
# After energy spectrum: 13677
# (array([93]),)
# (array([392]),)
# (array([673]),)
# (array([990]),)
# Iteration: 917  of  1000
# After the first cut: 369311
# After mass fractions: 108982
# After energy spectrum: 13724
# (array([72]),)
# (array([391]),)
# (array([671]),)
# (array([948]),)
# Iteration: 918  of  1000
# After the first cut: 369685
# After mass fractions: 108823
# After energy spectrum: 13777
# (array([94]),)
# (array([371]),)
# (array([672]),)
# (array([969]),)
# Iteration: 919  of  1000
# After the first cut: 369031
# After mass fractions: 108531
# After energy spectrum: 13573
# (array([92]),)
# (array([372]),)
# (array([671]),)
# (array([969]),)
# Iteration: 920  of  1000
# After the first cut: 369811
# After mass fractions: 109015
# After energy spectrum: 13627
# (array([94]),)
# (array([393]),)
# (array([693]),)
# (array([970]),)
# Iteration: 921  of  1000
# After the first cut: 369272
# After mass fractions: 108982
# After energy spectrum: 13728
# (array([91]),)
# (array([350]),)
# (array([649]),)
# (array([949]),)
# Iteration: 922  of  1000
# After the first cut: 368941
# After mass fractions: 108890
# After energy spectrum: 13763
# (array([94]),)
# (array([392]),)
# (array([672]),)
# (array([971]),)
# Iteration: 923  of  1000
# After the first cut: 369388
# After mass fractions: 108778
# After energy spectrum: 13712
# (array([94]),)
# (array([371]),)
# (array([692]),)
# (array([969]),)
# Iteration: 924  of  1000
# After the first cut: 369402
# After mass fractions: 108634
# After energy spectrum: 13858
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([949]),)
# Iteration: 925  of  1000
# After the first cut: 369428
# After mass fractions: 108901
# After energy spectrum: 13837
# (array([74]),)
# (array([392]),)
# (array([671]),)
# (array([949]),)
# Iteration: 926  of  1000
# After the first cut: 369309
# After mass fractions: 109235
# After energy spectrum: 13733
# (array([92]),)
# (array([372]),)
# (array([692]),)
# (array([948]),)
# Iteration: 927  of  1000
# After the first cut: 369637
# After mass fractions: 109116
# After energy spectrum: 13843
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([990]),)
# Iteration: 928  of  1000
# After the first cut: 369704
# After mass fractions: 109213
# After energy spectrum: 13935
# (array([93]),)
# (array([373]),)
# (array([672]),)
# (array([971]),)
# Iteration: 929  of  1000
# After the first cut: 369506
# After mass fractions: 108514
# After energy spectrum: 13775
# (array([72]),)
# (array([372]),)
# (array([691]),)
# (array([950]),)
# Iteration: 930  of  1000
# After the first cut: 369272
# After mass fractions: 109007
# After energy spectrum: 13538
# (array([92]),)
# (array([393]),)
# (array([672]),)
# (array([950]),)
# Iteration: 931  of  1000
# After the first cut: 369224
# After mass fractions: 108592
# After energy spectrum: 13462
# (array([92]),)
# (array([371]),)
# (array([672]),)
# (array([948]),)
# Iteration: 932  of  1000
# After the first cut: 369058
# After mass fractions: 108856
# After energy spectrum: 13585
# (array([93]),)
# (array([392]),)
# (array([650]),)
# (array([948]),)
# Iteration: 933  of  1000
# After the first cut: 369223
# After mass fractions: 108955
# After energy spectrum: 13573
# (array([51]),)
# (array([350]),)
# (array([647]),)
# (array([969]),)
# Iteration: 934  of  1000
# After the first cut: 369375
# After mass fractions: 108953
# After energy spectrum: 13789
# (array([74]),)
# (array([373]),)
# (array([670]),)
# (array([952]),)
# Iteration: 935  of  1000
# After the first cut: 369324
# After mass fractions: 108999
# After energy spectrum: 13788
# (array([73]),)
# (array([371]),)
# (array([650]),)
# (array([928]),)
# Iteration: 936  of  1000
# After the first cut: 369459
# After mass fractions: 108369
# After energy spectrum: 13605
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([951]),)
# Iteration: 937  of  1000
# After the first cut: 369143
# After mass fractions: 108645
# After energy spectrum: 13538
# (array([73]),)
# (array([390]),)
# (array([672]),)
# (array([970]),)
# Iteration: 938  of  1000
# After the first cut: 369641
# After mass fractions: 108918
# After energy spectrum: 13719
# (array([74]),)
# (array([392]),)
# (array([691]),)
# (array([950]),)
# Iteration: 939  of  1000
# After the first cut: 369579
# After mass fractions: 108571
# After energy spectrum: 13540
# (array([74]),)
# (array([391]),)
# (array([650]),)
# (array([970]),)
# Iteration: 940  of  1000
# After the first cut: 369387
# After mass fractions: 108314
# After energy spectrum: 13601
# (array([72]),)
# (array([372]),)
# (array([649]),)
# (array([928]),)
# Iteration: 941  of  1000
# After the first cut: 369573
# After mass fractions: 108893
# After energy spectrum: 13629
# (array([72]),)
# (array([351]),)
# (array([671]),)
# (array([969]),)
# Iteration: 942  of  1000
# After the first cut: 369458
# After mass fractions: 109161
# After energy spectrum: 13775
# (array([71]),)
# (array([350]),)
# (array([649]),)
# (array([949]),)
# Iteration: 943  of  1000
# After the first cut: 369513
# After mass fractions: 109064
# After energy spectrum: 13856
# (array([73]),)
# (array([370]),)
# (array([670]),)
# (array([970]),)
# Iteration: 944  of  1000
# After the first cut: 369093
# After mass fractions: 108930
# After energy spectrum: 13642
# (array([92]),)
# (array([371]),)
# (array([669]),)
# (array([948]),)
# Iteration: 945  of  1000
# After the first cut: 369465
# After mass fractions: 108962
# After energy spectrum: 13895
# (array([72]),)
# (array([371]),)
# (array([670]),)
# (array([947]),)
# Iteration: 946  of  1000
# After the first cut: 369170
# After mass fractions: 108385
# After energy spectrum: 13765
# (array([92]),)
# (array([392]),)
# (array([692]),)
# (array([972]),)
# Iteration: 947  of  1000
# After the first cut: 369392
# After mass fractions: 108793
# After energy spectrum: 13666
# (array([74]),)
# (array([372]),)
# (array([690]),)
# (array([970]),)
# Iteration: 948  of  1000
# After the first cut: 369260
# After mass fractions: 108968
# After energy spectrum: 13631
# (array([112]),)
# (array([392]),)
# (array([692]),)
# (array([970]),)
# Iteration: 949  of  1000
# After the first cut: 369170
# After mass fractions: 109017
# After energy spectrum: 13855
# (array([94]),)
# (array([411]),)
# (array([692]),)
# (array([1010]),)
# Iteration: 950  of  1000
# After the first cut: 369322
# After mass fractions: 108722
# After energy spectrum: 13764
# (array([92]),)
# (array([371]),)
# (array([672]),)
# (array([970]),)
# Iteration: 951  of  1000
# After the first cut: 369704
# After mass fractions: 109256
# After energy spectrum: 13898
# (array([94]),)
# (array([373]),)
# (array([672]),)
# (array([973]),)
# Iteration: 952  of  1000
# After the first cut: 370031
# After mass fractions: 109093
# After energy spectrum: 13517
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([992]),)
# Iteration: 953  of  1000
# After the first cut: 369405
# After mass fractions: 109123
# After energy spectrum: 14006
# (array([93]),)
# (array([392]),)
# (array([691]),)
# (array([951]),)
# Iteration: 954  of  1000
# After the first cut: 369534
# After mass fractions: 108489
# After energy spectrum: 13855
# (array([72]),)
# (array([370]),)
# (array([690]),)
# (array([948]),)
# Iteration: 955  of  1000
# After the first cut: 369386
# After mass fractions: 108850
# After energy spectrum: 13624
# (array([51]),)
# (array([349]),)
# (array([670]),)
# (array([926]),)
# Iteration: 956  of  1000
# After the first cut: 369263
# After mass fractions: 108668
# After energy spectrum: 13747
# (array([72]),)
# (array([370]),)
# (array([670]),)
# (array([927]),)
# Iteration: 957  of  1000
# After the first cut: 369333
# After mass fractions: 109394
# After energy spectrum: 13995
# (array([74]),)
# (array([371]),)
# (array([650]),)
# (array([950]),)
# Iteration: 958  of  1000
# After the first cut: 369355
# After mass fractions: 108982
# After energy spectrum: 13624
# (array([72]),)
# (array([371]),)
# (array([671]),)
# (array([951]),)
# Iteration: 959  of  1000
# After the first cut: 369313
# After mass fractions: 108978
# After energy spectrum: 13701
# (array([74]),)
# (array([371]),)
# (array([671]),)
# (array([971]),)
# Iteration: 960  of  1000
# After the first cut: 369678
# After mass fractions: 108963
# After energy spectrum: 13899
# (array([73]),)
# (array([372]),)
# (array([651]),)
# (array([969]),)
# Iteration: 961  of  1000
# After the first cut: 369571
# After mass fractions: 109110
# After energy spectrum: 13902
# (array([73]),)
# (array([392]),)
# (array([671]),)
# (array([971]),)
# Iteration: 962  of  1000
# After the first cut: 369302
# After mass fractions: 108717
# After energy spectrum: 13523
# (array([72]),)
# (array([391]),)
# (array([651]),)
# (array([949]),)
# Iteration: 963  of  1000
# After the first cut: 369225
# After mass fractions: 109040
# After energy spectrum: 13774
# (array([72]),)
# (array([391]),)
# (array([650]),)
# (array([969]),)
# Iteration: 964  of  1000
# After the first cut: 369179
# After mass fractions: 109110
# After energy spectrum: 13643
# (array([72]),)
# (array([371]),)
# (array([669]),)
# (array([970]),)
# Iteration: 965  of  1000
# After the first cut: 369401
# After mass fractions: 108903
# After energy spectrum: 13903
# (array([71]),)
# (array([371]),)
# (array([670]),)
# (array([947]),)
# Iteration: 966  of  1000
# After the first cut: 369412
# After mass fractions: 109365
# After energy spectrum: 13996
# (array([49]),)
# (array([350]),)
# (array([649]),)
# (array([970]),)
# Iteration: 967  of  1000
# After the first cut: 369393
# After mass fractions: 108885
# After energy spectrum: 13762
# (array([93]),)
# (array([391]),)
# (array([671]),)
# (array([948]),)
# Iteration: 968  of  1000
# After the first cut: 369358
# After mass fractions: 108947
# After energy spectrum: 13595
# (array([73]),)
# (array([372]),)
# (array([671]),)
# (array([950]),)
# Iteration: 969  of  1000
# After the first cut: 369246
# After mass fractions: 109089
# After energy spectrum: 13802
# (array([74]),)
# (array([391]),)
# (array([671]),)
# (array([971]),)
# Iteration: 970  of  1000
# After the first cut: 369359
# After mass fractions: 108848
# After energy spectrum: 13661
# (array([112]),)
# (array([393]),)
# (array([671]),)
# (array([991]),)
# Iteration: 971  of  1000
# After the first cut: 369386
# After mass fractions: 108838
# After energy spectrum: 13688
# (array([72]),)
# (array([372]),)
# (array([690]),)
# (array([970]),)
# Iteration: 972  of  1000
# After the first cut: 369620
# After mass fractions: 108774
# After energy spectrum: 13977
# (array([73]),)
# (array([371]),)
# (array([651]),)
# (array([949]),)
# Iteration: 973  of  1000
# After the first cut: 369392
# After mass fractions: 108674
# After energy spectrum: 13759
# (array([92]),)
# (array([392]),)
# (array([672]),)
# (array([949]),)
# Iteration: 974  of  1000
# After the first cut: 370031
# After mass fractions: 108818
# After energy spectrum: 13822
# (array([92]),)
# (array([372]),)
# (array([691]),)
# (array([969]),)
# Iteration: 975  of  1000
# After the first cut: 369721
# After mass fractions: 108980
# After energy spectrum: 13689
# (array([72]),)
# (array([371]),)
# (array([649]),)
# (array([948]),)
# Iteration: 976  of  1000
# After the first cut: 369493
# After mass fractions: 108660
# After energy spectrum: 13360
# (array([73]),)
# (array([372]),)
# (array([671]),)
# (array([949]),)
# Iteration: 977  of  1000
# After the first cut: 369470
# After mass fractions: 109038
# After energy spectrum: 13761
# (array([71]),)
# (array([370]),)
# (array([670]),)
# (array([948]),)
# Iteration: 978  of  1000
# After the first cut: 369504
# After mass fractions: 109252
# After energy spectrum: 13923
# (array([94]),)
# (array([373]),)
# (array([690]),)
# (array([990]),)
# Iteration: 979  of  1000
# After the first cut: 369367
# After mass fractions: 108567
# After energy spectrum: 13531
# (array([93]),)
# (array([392]),)
# (array([693]),)
# (array([973]),)
# Iteration: 980  of  1000
# After the first cut: 369339
# After mass fractions: 108509
# After energy spectrum: 13681
# (array([93]),)
# (array([392]),)
# (array([670]),)
# (array([970]),)
# Iteration: 981  of  1000
# After the first cut: 369572
# After mass fractions: 108842
# After energy spectrum: 13810
# (array([94]),)
# (array([393]),)
# (array([692]),)
# (array([954]),)
# Iteration: 982  of  1000
# After the first cut: 369534
# After mass fractions: 108578
# After energy spectrum: 13674
# (array([72]),)
# (array([351]),)
# (array([671]),)
# (array([948]),)
# Iteration: 983  of  1000
# After the first cut: 369256
# After mass fractions: 108828
# After energy spectrum: 13569
# (array([92]),)
# (array([373]),)
# (array([691]),)
# (array([974]),)
# Iteration: 984  of  1000
# After the first cut: 369192
# After mass fractions: 108969
# After energy spectrum: 13711
# (array([71]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 985  of  1000
# After the first cut: 369149
# After mass fractions: 108309
# After energy spectrum: 13516
# (array([73]),)
# (array([371]),)
# (array([671]),)
# (array([949]),)
# Iteration: 986  of  1000
# After the first cut: 369801
# After mass fractions: 108988
# After energy spectrum: 13864
# (array([70]),)
# (array([371]),)
# (array([649]),)
# (array([926]),)
# Iteration: 987  of  1000
# After the first cut: 369452
# After mass fractions: 109100
# After energy spectrum: 13706
# (array([71]),)
# (array([371]),)
# (array([670]),)
# (array([949]),)
# Iteration: 988  of  1000
# After the first cut: 369234
# After mass fractions: 108813
# After energy spectrum: 13689
# (array([74]),)
# (array([372]),)
# (array([671]),)
# (array([971]),)
# Iteration: 989  of  1000
# After the first cut: 369348
# After mass fractions: 108941
# After energy spectrum: 13774
# (array([93]),)
# (array([373]),)
# (array([649]),)
# (array([969]),)
# Iteration: 990  of  1000
# After the first cut: 369642
# After mass fractions: 109032
# After energy spectrum: 13858
# (array([93]),)
# (array([372]),)
# (array([670]),)
# (array([972]),)
# Iteration: 991  of  1000
# After the first cut: 369512
# After mass fractions: 109001
# After energy spectrum: 13659
# (array([92]),)
# (array([391]),)
# (array([673]),)
# (array([950]),)
# Iteration: 992  of  1000
# After the first cut: 369561
# After mass fractions: 108557
# After energy spectrum: 13780
# (array([93]),)
# (array([392]),)
# (array([692]),)
# (array([991]),)
# Iteration: 993  of  1000
# After the first cut: 369360
# After mass fractions: 108920
# After energy spectrum: 13818
# (array([93]),)
# (array([391]),)
# (array([671]),)
# (array([929]),)
# Iteration: 994  of  1000
# After the first cut: 369849
# After mass fractions: 109186
# After energy spectrum: 13825
# (array([94]),)
# (array([373]),)
# (array([671]),)
# (array([970]),)
# Iteration: 995  of  1000
# After the first cut: 369566
# After mass fractions: 108714
# After energy spectrum: 13589
# (array([73]),)
# (array([371]),)
# (array([691]),)
# (array([970]),)
# Iteration: 996  of  1000
# After the first cut: 369222
# After mass fractions: 108797
# After energy spectrum: 13559
# (array([93]),)
# (array([392]),)
# (array([672]),)
# (array([929]),)
# Iteration: 997  of  1000
# After the first cut: 369740
# After mass fractions: 109093
# After energy spectrum: 13995
# (array([71]),)
# (array([371]),)
# (array([649]),)
# (array([947]),)
# Iteration: 998  of  1000
# After the first cut: 369545
# After mass fractions: 108905
# After energy spectrum: 13871
# (array([93]),)
# (array([411]),)
# (array([711]),)
# (array([990]),)
# Iteration: 999  of  1000
# After the first cut: 369361
# After mass fractions: 108502
# After energy spectrum: 13579
# (array([93]),)
# (array([373]),)
# (array([671]),)
# (array([950]),)
# Iteration: 1000  of  1000
# After the first cut: 369575
# After mass fractions: 108985
# After energy spectrum: 13714
# (array([72]),)
# (array([371]),)
# (array([650]),)
# (array([949]),)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 94
#      90         final_results['frac_h'].append(frac_h)
#      93 for key, value in final_results.items():
# ---> 94     final_results[key] = np.array(value)
#      95 display(final_results)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4000,) + inhomogeneous part.

# %%
display(final_results)
print(len(final_results['light']))
# Out:
# {'iter': array([  0,   0,   0, ..., 999, 999, 999]),
#  'emin': array([ 4.,  8., 16., ...,  8., 16., 32.]),
#  'light': [array([818.8524], dtype=float32),
#   array([788.943], dtype=float32),
#   array([773.9883], dtype=float32),
#   array([773.9883], dtype=float32),
#   array([807.68896], dtype=float32),
#   array([778.1587], dtype=float32),
#   array([745.5692], dtype=float32),
#   array([727.79083], dtype=float32),
#   array([748.1499], dtype=float32),
#   array([748.1499], dtype=float32),
#   array([730.1018], dtype=float32),
#   array([712.05365], dtype=float32),
#   array([753.7272], dtype=float32),
#   array([738.6397], dtype=float32),
#   array([738.6397], dtype=float32),
#   array([753.7272], dtype=float32),
#   array([746.6871], dtype=float32),
#   array([732.3849], dtype=float32),
#   array([732.3849], dtype=float32),
#   array([732.3849], dtype=float32),
#   array([745.5467], dtype=float32),
#   array([745.5467], dtype=float32),
#   array([727.38025], dtype=float32),
#   array([709.21387], dtype=float32),
#   array([735.8626], dtype=float32),
#   array([735.8626], dtype=float32),
#   array([749.86865], dtype=float32),
#   array([735.8626], dtype=float32),
#   array([749.86804], dtype=float32),
#   array([732.2851], dtype=float32),
#   array([732.2851], dtype=float32),
#   array([732.2851], dtype=float32),
#   array([742.10364], dtype=float32),
#   array([728.2872], dtype=float32),
#   array([742.10364], dtype=float32),
#   array([714.4707], dtype=float32),
#   array([744.2163], dtype=float32),
#   array([744.2163], dtype=float32),
#   array([744.2163], dtype=float32),
#   array([715.6659], dtype=float32),
#   array([751.2123], dtype=float32),
#   array([736.00507], dtype=float32),
#   array([720.7978], dtype=float32),
#   array([720.7978], dtype=float32),
#   array([743.9304], dtype=float32),
#   array([743.9304], dtype=float32),
#   array([727.56445], dtype=float32),
#   array([743.9304], dtype=float32),
#   array([739.9155], dtype=float32),
#   array([724.3068], dtype=float32),
# ...
#   array([0.30783242]),
#   array([0.512]),
#   array([0.26387334]),
#   array([0.19483682]),
#   array([0.4038835]),
#   array([0.296]),
#   array([0.28674897]),
#   array([0.3492891]),
#   array([0.45855379]),
#   array([0.40714286]),
#   array([0.34868629]),
#   array([0.25815739]),
#   array([0.19926199]),
#   array([0.39516129]),
#   array([0.29101816]),
#   array([0.34050881]),
#   array([0.2562724]),
#   array([0.62406015]),
#   array([0.24790458]),
#   array([0.16267043]),
#   array([0.22043011]),
#   array([0.40909091]),
#   array([0.26625687]),
#   array([0.32395038]),
#   array([0.4118705]),
#   array([0.67910448]),
#   array([0.27657821]),
#   array([0.16593245]),
#   array([0.42379182]),
#   array([0.36428571]),
#   array([0.21169191]),
#   array([0.26378539]),
#   array([0.33270321]),
#   array([0.57352941]),
#   array([0.33079169]),
#   array([0.40047281]),
#   array([0.26430976]),
#   array([0.51304348]),
#   array([0.28525069]),
#   array([0.32587549]),
#   array([0.55534351]),
#   array([0.5942029]),
#   array([0.28632338]),
#   array([0.18125887]),
#   array([0.42084942]),
#   array([0.22302158]),
#   array([0.31120801]),
#   array([0.22061031]),
#   array([0.20566038]),
#   array([0.6969697]),
#   array([0.28447144]),
#   array([0.16957364]),
#   array([0.27468582]),
#   array([0.62698413]),
#   array([0.30543173]),
#   array([0.23923679]),
#   array([0.44854369]),
#   array([0.60150376]),
#   array([0.31303783]),
#   array([0.2327044]),
#   array([0.44554455]),
#   array([0.36879433]),
#   array([0.19512998]),
#   array([0.40484101]),
#   array([0.48623853]),
#   array([0.37903226]),
#   array([0.20164069]),
#   array([0.26070409]),
#   array([0.3590604]),
#   array([0.42142857]),
#   array([0.29874776]),
#   array([0.23784804]),
#   array([0.49537893]),
#   array([0.31007752]),
#   array([0.2593317]),
#   array([0.3005698]),
#   array([0.23463687]),
#   array([0.49166667]),
#   array([0.22524396]),
#   array([0.27640037]),
#   array([0.394]),
#   array([0.48965517]),
#   array([0.35692056]),
#   array([0.2617606]),
#   array([0.51712329]),
#   array([0.37414966]),
#   array([0.34519401]),
#   array([0.24791086]),
#   array([0.46607143]),
#   array([0.52980132]),
#   array([0.20022354]),
#   array([0.39480137]),
#   array([0.45951036]),
#   array([0.38970588]),
#   array([0.19941397]),
#   array([0.23681733]),
#   array([0.34854015]),
#   array([0.51388889]),
#   array([0.25048988]),
#   array([0.29654837]),
#   array([0.52372263]),
#   array([0.58450704]),
#   array([0.28301282]),
#   array([0.31824611]),
#   array([0.30540037]),
#   array([0.42857143]),
#   array([0.20477428]),
#   array([0.40149743]),
#   array([0.5696649]),
#   array([0.21311475]),
#   array([0.23460317]),
#   array([0.28385542]),
#   array([0.38461538]),
#   array([0.5462963]),
#   array([0.19663731]),
#   array([0.23883495]),
#   array([0.34608379]),
#   array([0.50694444]),
#   array([0.26820488]),
#   array([0.33253244]),
#   array([0.3877551]),
#   array([0.63934426]),
#   array([0.33876221]),
#   array([0.2642824]),
#   array([0.37087379]),
#   array([0.38235294]),
#   array([0.20266795]),
#   array([0.38083775]),
#   array([0.44692737]),
#   array([0.49275362]),
#   array([0.29686243]),
#   array([0.22385932]),
#   array([0.45920304]),
#   array([0.49390244]),
#   array([0.20745033]),
#   array([0.25122669]),
#   array([0.49632353]),
#   array([0.42537313]),
#   array([0.25686113]),
#   array([0.31606715]),
#   array([0.38814532]),
#   array([0.34210526]),
#   array([0.33654928]),
#   array([0.24437781]),
#   array([0.4844358]),
#   array([0.34883721]),
#   array([0.31915934]),
#   array([0.23377234]),
#   array([0.35920578]),
#   array([0.57364341]),
#   array([0.19694344]),
#   array([0.24568966]),
#   array([0.46350365]),
#   array([0.57364341]),
#   array([0.32586069]),
#   array([0.24976393]),
#   array([0.31851852]),
#   array([0.33333333]),
#   array([0.24590985]),
#   array([0.29878345]),
#   array([0.24444444]),
#   array([0.76]),
#   array([0.20626458]),
#   array([0.26306141]),
#   array([0.45920304]),
#   array([0.45517241]),
#   array([0.31992213]),
#   array([0.21252465]),
#   array([0.44216418]),
#   array([0.25471698]),
#   array([0.27765905]),
#   array([0.33349538]),
#   array([0.52804642]),
#   array([0.41935484]),
#   array([0.27242206]),
#   array([0.18240147]),
#   array([0.42778793]),
#   array([0.5546875]),
#   array([0.30170473]),
#   array([0.35548327]),
#   array([0.44945848]),
#   array([0.39837398]),
#   array([0.16234719]),
#   array([0.20592318]),
#   array([0.25939177]),
#   array([0.46153846]),
#   array([0.2153525]),
#   array([0.27013989]),
#   array([0.20499109]),
#   array([0.5177305]),
#   array([0.19811321]),
#   array([0.25669752]),
#   array([0.28415301]),
#   array([0.48120301]),
#   array([0.26884546]),
#   array([0.19934334]),
#   array([0.3844732]),
#   array([0.30379747]),
#   array([0.22982569]),
#   array([0.25872093]),
#   array([0.47080979]),
#   array([0.336]),
#   array([0.35962502]),
#   array([0.28488653]),
#   array([0.21923077]),
#   array([0.50344828]),
#   array([0.33095804]),
#   array([0.26054591]),
#   array([0.34452297]),
#   array([0.54744526]),
#   array([0.19958119]),
#   array([0.24353343]),
#   array([0.33333333]),
#   array([0.4]),
#   array([0.18430421]),
#   array([0.35178998]),
#   array([0.31834532]),
#   array([0.36842105]),
#   array([0.3175285]),
#   array([0.38987952]),
#   array([0.45643154]),
#   array([0.32758621]),
#   array([0.34790997]),
#   array([0.2386811]),
#   array([0.49367089]),
#   array([0.50434783]),
#   array([0.32623191]),
#   array([0.39482674]),
#   array([0.37058824]),
#   array([0.50769231]),
#   array([0.19846204]),
#   array([0.24368932]),
#   array([0.48084291]),
#   array([0.52592593]),
#   array([0.23145202]),
#   array([0.27018044]),
#   array([0.35969868]),
#   array([0.59375]),
#   array([0.35918033]),
#   array([0.27659574]),
#   array([0.51201479]),
#   array([0.58666667]),
#   array([0.34725556]),
#   array([0.24939933]),
#   array([0.49438202]),
#   array([0.47413793]),
#   array([0.28751617]),
#   array([0.22560685]),
#   array([0.30659537]),
#   array([0.21428571]),
#   array([0.23832475]),
#   array([0.30086372]),
#   array([0.24352332]),
#   array([0.49264706]),
#   array([0.2954471]),
#   array([0.3651472]),
#   array([0.48975791]),
#   array([0.44202899]),
#   array([0.30273596]),
#   array([0.34814099]),
#   array([0.42941176]),
#   array([0.25]),
#   array([0.23981686]),
#   array([0.28439922]),
#   array([0.37132353]),
#   array([0.45967742]),
#   array([0.2319301]),
#   array([0.27843719]),
#   array([0.22900763]),
#   array([0.5648855]),
#   array([0.25244901]),
#   array([0.31325886]),
#   array([0.41477273]),
#   array([0.33050847]),
#   array([0.31815941]),
#   array([0.37676388]),
#   array([0.28729282]),
#   array([0.49640288]),
#   array([0.2494718]),
#   array([0.30430667]),
#   array([0.4037037]),
#   array([0.54285714]),
#   array([0.26147382]),
#   array([0.32689522]),
#   array([0.44604317]),
#   array([0.41322314]),
#   array([0.31428106]),
#   array([0.39749156]),
#   array([0.31215971]),
#   array([0.4887218]),
#   array([0.33207485]),
#   array([0.21042377]),
#   array([0.28397566]),
#   array([0.47580645]),
#   array([0.33801692]),
#   array([0.37457709]),
#   array([0.5056391]),
#   array([0.35433071]),
#   array([0.27846874]),
#   array([0.32766164]),
#   array([0.29982964]),
#   array([0.36752137]),
#   array([0.31255154]),
#   array([0.371139]),
#   array([0.31657356]),
#   array([0.421875]),
#   array([0.27997397]),
#   array([0.34023529]),
#   array([0.44833625]),
#   array([0.43165468]),
#   array([0.27049447]),
#   array([0.29428571]),
#   array([0.43680297]),
#   array([0.56390977]),
#   array([0.20831312]),
#   array([0.25269872]),
#   array([0.31386861]),
#   array([0.34693878]),
#   array([0.26079253]),
#   array([0.31019202]),
#   array([0.41573034]),
#   array([0.60144928]),
#   array([0.25667417]),
#   array([0.31692913]),
#   array([0.40115163]),
#   array([0.51639344]),
#   array([0.34546345]),
#   array([0.2577863]),
#   array([0.49100719]),
#   array([0.45522388]),
#   array([0.22898884]),
#   array([0.27703349]),
#   array([0.47173489]),
#   array([0.44715447]),
#   array([0.31767677]),
#   array([0.25309229]),
#   array([0.4965035]),
#   array([0.34108527]),
#   array([0.24541063]),
#   array([0.3245572]),
#   array([0.38768116]),
#   array([0.43965517]),
#   array([0.30122649]),
#   array([0.34327652]),
#   array([0.44006849]),
#   array([0.63716814]),
#   array([0.31984334]),
#   array([0.2056213]),
#   array([0.31360947]),
#   array([0.44680851]),
#   array([0.30413625]),
#   array([0.36376882]),
#   array([0.44789762]),
#   array([0.42424242]),
#   array([0.2815708]),
#   array([0.17792268]),
#   array([0.40740741]),
#   array([0.40310078]),
#   array([0.35672609]),
#   array([0.26717196]),
#   array([0.3358349]),
#   array([0.38461538]),
#   array([0.25407432]),
#   array([0.30345835]),
#   array([0.23674242]),
#   array([0.53846154]),
#   array([0.28483436]),
#   array([0.19820246]),
#   array([0.44]),
#   array([0.5648855]),
#   array([0.28343281]),
#   array([0.32981783]),
#   array([0.47410359]),
#   array([0.36585366]),
#   array([0.30609555]),
#   array([0.23590226]),
#   array([0.58453237]),
#   array([0.3852459]),
#   array([0.29033301]),
#   array([0.3655239]),
#   array([0.57335907]),
#   array([0.29078014]),
#   array([0.23840842]),
#   array([0.29665072]),
#   array([0.54819277]),
#   array([0.4084507]),
#   array([0.22909809]),
#   array([0.28063611]),
#   array([0.37798165]),
#   array([0.43478261]),
#   array([0.31336863]),
#   array([0.3647343]),
#   array([0.44190476]),
#   array([0.41269841]),
#   array([0.30710454]),
#   array([0.36407533]),
#   array([0.25090253]),
#   array([0.45588235]),
#   array([0.42885638]),
#   array([0.33824228]),
#   array([0.42509363]),
#   array([0.59854015]),
#   array([0.37021073]),
#   array([0.25546059]),
#   array([0.3982906]),
#   array([0.3984375]),
#   array([0.31206365]),
#   array([0.25]),
#   array([0.4370229]),
#   array([0.22556391]),
#   array([0.35228209]),
#   array([0.24831244]),
#   array([0.32495512]),
#   array([0.54471545]),
#   array([0.27815755]),
#   array([0.2138395]),
#   array([0.12989691]),
#   array([0.33050847]),
#   array([0.30200064]),
#   array([0.3423939]),
#   array([0.30223881]),
#   array([0.51304348]),
#   array([0.34893893]),
#   array([0.43498597]),
#   array([0.51176471]),
#   array([0.50364964]),
#   array([0.2446877]),
#   array([0.29371651]),
#   array([0.3794964]),
#   array([0.37956204]),
#   array([0.36873298]),
#   array([0.42836114]),
#   array([0.38791423]),
#   array([0.4965035]),
#   array([0.28190293]),
#   array([0.32573599]),
#   array([0.26111111]),
#   array([0.43076923]),
#   array([0.25986789]),
#   array([0.30838041]),
#   array([0.39964476]),
#   array([0.29577465]),
#   array([0.28879804]),
#   array([0.21042471]),
#   array([0.25858951]),
#   array([0.375]),
#   array([0.32242915]),
#   array([0.24399804]),
#   array([0.46065259]),
#   array([0.32307692]),
#   array([0.24132877]),
#   array([0.30718954]),
#   array([0.38378378]),
#   array([0.70068027]),
#   array([0.30874898]),
#   array([0.35996196]),
#   array([0.47313692]),
#   array([0.67889908]),
#   array([0.22548706]),
#   array([0.27409201]),
#   array([0.21150278]),
#   array([0.58536585]),
#   array([0.31454396]),
#   array([0.23307912]),
#   array([0.48948375]),
#   array([0.2]),
#   array([0.25786059]),
#   array([0.31824678]),
#   array([0.38518519]),
#   array([0.68253968]),
#   array([0.34294976]),
#   array([0.26760563]),
#   array([0.35583942]),
#   array([0.64]),
#   array([0.31287644]),
#   array([0.36278381]),
#   array([0.32780847]),
#   array([0.56]),
#   array([0.32001294]),
#   array([0.38391575]),
#   array([0.49475524]),
#   array([0.41007194]),
#   array([0.29378802]),
#   array([0.34782609]),
#   array([0.28816794]),
#   array([0.55813953]),
#   array([0.24025012]),
#   array([0.29785156]),
#   array([0.36580882]),
#   array([0.48387097]),
#   array([0.24556119]),
#   array([0.29569892]),
#   array([0.36775362]),
#   array([0.26923077]),
#   array([0.24127343]),
#   array([0.29860465]),
#   array([0.20670391]),
#   array([0.56]),
#   array([0.19870303]),
#   array([0.25404377]),
#   array([0.33148148]),
#   array([0.50420168]),
#   array([0.32153392]),
#   array([0.21870504]),
#   array([0.43283582]),
#   array([0.46621622]),
#   array([0.18833636]),
#   array([0.36355007]),
#   array([0.32899628]),
#   array([0.46969697]),
#   array([0.22282519]),
#   array([0.28456819]),
#   array([0.51182432]),
#   array([0.54074074]),
#   array([0.33154994]),
#   array([0.38281623]),
#   array([0.33212996]),
#   array([0.70992366]),
#   array([0.2799477]),
#   array([0.34778466]),
#   array([0.41269841]),
#   array([0.71755725]),
#   array([0.32315772]),
#   array([0.21199245]),
#   array([0.25825243]),
#   array([0.46511628]),
#   array([0.1990172]),
#   array([0.24059076]),
#   array([0.43233083]),
#   array([0.64227642]),
#   array([0.35126377]),
#   array([0.24667932]),
#   array([0.28316832]),
#   array([0.55725191]),
#   array([0.25880825]),
#   array([0.28720238]),
#   array([0.52150538]),
#   array([0.41258741]),
#   array([0.27736399]),
#   array([0.31484185]),
#   array([0.44786325]),
#   array([0.5648855]),
#   array([0.2910596]),
#   array([0.36053769]),
#   array([0.31028037]),
#   array([0.45454545]),
#   array([0.24391052]),
#   array([0.17669532]),
#   array([0.39488117]),
#   array([0.53543307]),
#   array([0.28854337]),
#   array([0.33269962]),
#   array([0.23900574]),
#   array([0.60283688]),
#   array([0.22119291]),
#   array([0.27102355]),
#   array([0.35955056]),
#   array([0.52066116]),
#   array([0.15390879]),
#   array([0.3611898]),
#   array([0.58608696]),
#   array([0.43333333]),
#   array([0.28043018]),
#   array([0.34559851]),
#   array([0.40413534]),
#   array([0.68531469]),
#   array([0.24554006]),
#   array([0.28463357]),
#   array([0.38515901]),
#   array([0.44444444]),
#   array([0.19718076]),
#   array([0.37311984]),
#   array([0.30656934]),
#   array([0.42142857]),
#   array([0.2519685]),
#   array([0.29682152]),
#   array([0.42776735]),
#   array([0.5]),
#   array([0.32379421]),
#   array([0.23486683]),
#   array([0.34980989]),
#   array([0.47586207]),
#   array([0.31470013]),
#   array([0.35992311]),
#   array([0.31599229]),
#   array([0.42342342]),
#   array([0.29072232]),
#   array([0.33788707]),
#   array([0.4410058]),
#   array([0.62237762]),
#   array([0.33668756]),
#   array([0.40531401]),
#   array([0.3380531]),
#   array([0.32592593]),
#   array([0.31809962]),
#   array([0.23026973]),
#   array([0.4800759]),
#   array([0.52713178]),
#   array([0.28874735]),
#   array([0.33602662]),
#   array([0.24587156]),
#   array([0.34482759]),
#   array([0.24472781]),
#   array([0.30947867]),
#   array([0.39530333]),
#   array([0.68644068]),
#   array([0.2408867]),
#   array([0.28392685]),
#   array([0.35460993]),
#   array([0.36879433]),
#   array([0.25805921]),
#   array([0.31464908]),
#   array([0.24067164]),
#   array([0.54814815]),
#   array([0.3151982]),
#   array([0.25935288]),
#   array([0.19074074]),
#   array([0.4965035]),
#   array([0.16734428]),
#   array([0.21174799]),
#   array([0.44315992]),
#   array([0.41935484]),
#   array([0.31002105]),
#   array([0.22760646]),
#   array([0.3442029]),
#   array([0.52631579]),
#   array([0.2255368]),
#   array([0.27181545]),
#   array([0.50961538]),
#   array([0.45255474]),
#   array([0.2352455]),
#   array([0.2738268]),
#   array([0.36507937]),
#   array([0.57017544]),
#   array([0.3479394]),
#   array([0.27395934]),
#   array([0.34410646]),
#   array([0.55725191]),
#   array([0.31143317]),
#   array([0.36746693]),
#   array([0.27102804]),
#   array([0.45669291]),
#   array([0.21392467]),
#   array([0.40790123]),
#   array([0.53641208]),
#   array([0.5]),
#   array([0.35773572]),
#   array([0.41423794]),
#   array([0.35336976]),
#   array([0.28947368]),
#   array([0.26082612]),
#   array([0.30513308]),
#   array([0.23741007]),
#   array([0.16793893]),
#   array([0.18643233]),
#   array([0.21993127]),
#   array([0.30037313]),
#   array([0.63513514]),
#   array([0.25171042]),
#   array([0.16579073]),
#   array([0.40467626]),
#   array([0.5078125]),
#   array([0.30020737]),
#   array([0.35633803]),
#   array([0.42007435]),
#   array([0.38732394]),
#   array([0.26745523]),
#   array([0.48024012]),
#   array([0.28205128]),
#   array([0.45714286]),
#   array([0.24512854]),
#   array([0.1813447]),
#   array([0.37749546]),
#   array([0.37313433]),
#   array([0.30447114]),
#   array([0.36612529]),
#   array([0.32447818]),
#   array([0.421875]),
#   array([0.15238407]),
#   array([0.35283107]),
#   array([0.4470377]),
#   array([0.47540984]),
#   array([0.30615533]),
#   array([0.24680246]),
#   array([0.45907473]),
#   array([0.19727891]),
#   array([0.26472012]),
#   array([0.18011527]),
#   array([0.4010327]),
#   array([0.34579439]),
#   array([0.2855728]),
#   array([0.34165443]),
#   array([0.28224299]),
#   array([0.60169492]),
#   array([0.19761252]),
#   array([0.25189753]),
#   array([0.3683274]),
#   array([0.26356589]),
#   array([0.32701959]),
#   array([0.2278658]),
#   array([0.49360146]),
#   array([0.38518519]),
#   ...]}
# 4000

# %%
np.save('results.npy', final_results)
df = pd.DataFrame(final_results)
df.to_csv("final_results.csv", index=False)
