# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast

df = pd.read_csv('partial_results_univ.csv')
display(df)

# for col in ["light", "heavy", "frac_l", "frac_h"]:  # Adjust column names if needed
#     df[col] = df[col].apply(lambda x: ast.literal_eval(x)[0] if isinstance(x, str) else x)
# Out:
#       iter  emin       light       heavy    frac_l    frac_h
# 0        0   4.0  846.843363  741.574746  0.145935  0.355534
# 1        0   8.0  804.735916  762.628469  0.186851  0.550173
# 2        0  16.0  783.682193  762.628469  0.182022  0.675281
# 3        0  32.0  804.735916  720.521023  0.060345  0.439655
# 4        1   4.0  934.642608  704.048720  0.013372  0.205349
# ...    ...   ...         ...         ...       ...       ...
# 3995   998  32.0  818.546596  760.378973  0.039326  0.724719
# 3996   999   4.0  928.299107  697.812555  0.021926  0.200191
# 3997   999   8.0  781.625847  739.719201  0.304193  0.415700
# 3998   999  16.0  802.579169  739.719201  0.102207  0.440186
# 3999   999  32.0  802.579169  697.812555  0.053254  0.275148
#
# [4000 rows x 6 columns]

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)], histtype='step', stacked=True, fill=False, color=colors[f'{ene}'], lw=4, alpha=0.8)
    plt.axvline(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of lightest events')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)], histtype='step', fill=False, color=colors[f'{ene}'], lw=4, alpha=0.8)
    plt.axvline(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of heaviest events')
plt.ylabel('# simulated data sets')
plt.show()


# da ChatGPT perché sono pigro cazzo
fig, axs = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# First plot: fraction of lightest events
for i in range(len(energ[:-1])):
    ene = energ[i]
    data_l = df['frac_l'][(df['emin'] == ene) & (df['frac_l'] != 0)]
    mean_l = np.mean(data_l)
    axs[0].hist(data_l, histtype='step', stacked=True, fill=False,
                color=colors[f'{ene}'], lw=4, alpha=0.8)
    axs[0].axvline(mean_l, ls='--', lw=4, color=colors[f'{ene}'],
                   label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_l:.2f}$')
    print(mean_l)

axs[0].legend()
axs[0].set_xlim(0.01, 0.8)
axs[0].set_xlabel('fraction of lightest events')
axs[0].set_ylabel('# simulated data sets')

# Second plot: fraction of heaviest events
for i in range(len(energ[:-1])):
    ene = energ[i]
    data_h = df['frac_h'][(df['emin'] == ene) & (df['frac_h'] != 0)]
    mean_h = np.mean(data_h)
    axs[1].hist(data_h, histtype='step', fill=False,
                color=colors[f'{ene}'], lw=4, alpha=0.8)
    axs[1].axvline(mean_h, ls='--', lw=4, color=colors[f'{ene}'],
                   label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_h:.2f}$')
    print(mean_h)

axs[1].legend()
axs[1].set_xlim(0.01, 0.8)
axs[1].set_xlabel('fraction of heaviest events')
axs[1].set_ylabel('# simulated data sets')
axs[1].tick_params(labelleft=True)

# plt.tight_layout()
plt.show()


print(len(df['frac_l'][(df['frac_l']!=0)]))
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:40: SyntaxWarning: invalid escape sequence '\,'
# <>:56: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:40: SyntaxWarning: invalid escape sequence '\,'
# <>:56: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_148424/3332563836.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_148424/3332563836.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_148424/3332563836.py:40: SyntaxWarning: invalid escape sequence '\,'
#   label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_l:.2f}$')
# /tmp/ipykernel_148424/3332563836.py:56: SyntaxWarning: invalid escape sequence '\,'
#   label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_h:.2f}$')
# 0.15994517398047417
# 0.09816993201235387
# 0.08651320486293747
# 0.5091879010354867
# 0.49953155550619094
# 0.49722825944261717
# 0.15994517398047417
# 0.09816993201235387
# 0.08651320486293747
# 0.5091879010354867
# 0.49953155550619094
# 0.49722825944261717
# 4000

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['light'][df['emin']==ene], histtype='step', stacked=False, fill=False, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['light'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'light threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['heavy'][df['emin']==ene], histtype='step', fill=False, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['heavy'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'heavy threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()
# Out:
# 816.0454180511892
# 813.0115053170889
# 803.8562578428382
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_148424/2445220404.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_148424/2445220404.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# 754.7270184937081
# 742.0024824263023
# 723.4723818574253
