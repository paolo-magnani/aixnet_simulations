# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast

df = pd.read_csv('final_results.csv')
display(df)

for col in ["light", "heavy", "frac_l", "frac_h"]:  # Adjust column names if needed
    df[col] = df[col].apply(lambda x: ast.literal_eval(x)[0] if isinstance(x, str) else x)
# Out:
#       iter  emin        light        heavy        frac_l        frac_h
# 0        0   4.0   [818.8524]  [744.07886]  [0.15699208]  [0.28644459]
# 1        0   8.0    [788.943]  [744.07886]  [0.28281853]  [0.35135135]
# 2        0  16.0   [773.9883]  [729.12415]   [0.2891791]  [0.27425373]
# 3        0  32.0   [773.9883]  [729.12415]  [0.12676056]  [0.48591549]
# 4        1   4.0  [807.68896]   [748.6284]  [0.21084822]   [0.3228714]
# ...    ...   ...          ...          ...           ...           ...
# 3995   998  32.0  [775.22144]  [718.52423]  [0.13793103]  [0.43103448]
# 3996   999   4.0  [804.13074]   [742.0914]  [0.23587547]  [0.26272443]
# 3997   999   8.0   [788.6209]   [742.0914]  [0.27901468]  [0.31549029]
# 3998   999  16.0   [788.6209]  [726.58154]  [0.18888889]  [0.26296296]
# 3999   999  32.0   [773.1111]  [726.58154]  [0.19047619]   [0.5170068]
#
# [4000 rows x 6 columns]

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_l'][df['emin']==ene], histtype='step', stacked=False, fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['frac_l'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_l'][df['emin']==ene]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of lightest events')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_h'][df['emin']==ene], histtype='step', fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['frac_h'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_h'][df['emin']==ene]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of heaviest events')
plt.ylabel('# simulated data sets')
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_35830/2209908922.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_l'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_35830/2209908922.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_h'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# 0.26252216438
# 0.27375501831000004
# 0.21206223788
# 0.29392718981
# 0.3748519285
# 0.45758987204

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['light'][df['emin']==ene], histtype='step', stacked=False, fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['light'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'light threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['heavy'][df['emin']==ene], histtype='step', fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['heavy'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'heavy threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_35830/845556194.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_35830/845556194.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# 791.81409702
# 780.74917046
# 773.09660611
# 739.1430837999999
# 738.50995066
# 728.5889655000001
