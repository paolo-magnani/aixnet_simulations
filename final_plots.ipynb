# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast

df = pd.read_csv('final_results_kane.csv')
display(df)

for col in ["light", "heavy", "frac_l", "frac_h"]:  # Adjust column names if needed
    df[col] = df[col].apply(lambda x: ast.literal_eval(x)[0] if isinstance(x, str) else x)
# Out:
#       iter  emin       light       heavy    frac_l    frac_h
# 0        0   4.0  797.192914  762.470979  0.321042  0.397759
# 1        0   8.0  797.192914  745.110011  0.218655  0.336831
# 2        0  16.0  797.192914  745.110011  0.133087  0.447288
# 3        0  32.0  779.831946  727.749044  0.114168  0.430016
# 4        1   4.0  813.073862  743.689089  0.218548  0.240137
# ...    ...   ...         ...         ...       ...       ...
# 3995   998  32.0  787.355935  732.539054  0.084569  0.485993
# 3996   999   4.0  813.216820  759.101261  0.224105  0.365247
# 3997   999   8.0  813.216820  741.062742  0.139950  0.292094
# 3998   999  16.0  795.178300  741.062742  0.140285  0.403386
# 3999   999  32.0  795.178300  723.024223  0.062840  0.365963
#
# [4000 rows x 6 columns]

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)], histtype='step', stacked=False, fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of lightest events')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)], histtype='step', fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]))
plt.legend()
plt.xlim(0.01, 0.8)
plt.xlabel('fraction of heaviest events')
plt.ylabel('# simulated data sets')
plt.show()

print(len(df['frac_l'][(df['frac_l']!=0)]))
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_50341/4210547437.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_50341/4210547437.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# 0.20843783975420604
# 0.14356108702698747
# 0.09140284434955981
# 0.36099434111738266
# 0.45997374342222513
# 0.43921505853376763
# 4000

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['light'][df['emin']==ene], histtype='step', stacked=False, fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['light'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'light threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['heavy'][df['emin']==ene], histtype='step', fill=True, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
    print(np.mean(df['heavy'][df['emin']==ene]))
plt.legend()
plt.xlim(700.1, 850)
plt.xlabel(r'heavy threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()
# Out:
# 799.1343196901001
# 795.0310808245131
# 785.7182554102146
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_50341/845556194.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_50341/845556194.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.0f}$', color=colors[f'{ene}'])
# 747.7355028193889
# 746.2460782030988
# 728.852555381662
