# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast

df = pd.read_csv('data_results/final_results_aixnet_sybill23d.csv')
display(df)

# for col in ["light", "heavy", "frac_l", "frac_h"]:  # Adjust column names if needed
#     df[col] = df[col].apply(lambda x: ast.literal_eval(x)[0] if isinstance(x, str) else x)
# Out:
#       iter  emin       light       heavy    frac_l    frac_h
# 0        0   8.0  795.022443  745.420815  0.284976  0.319356
# 1        0  16.0  778.488567  745.420815  0.306629  0.402484
# 2        0  32.0  778.488567  728.886939  0.188847  0.420814
# 3        1   8.0  798.682583  748.867760  0.254633  0.351397
# 4        1  16.0  782.077642  748.867760  0.287551  0.437578
# ...    ...   ...         ...         ...       ...       ...
# 2995   998  16.0  783.160903  750.065048  0.277935  0.436881
# 2996   998  32.0  766.612976  733.517121  0.255764  0.473411
# 2997   999   8.0  788.617879  747.444947  0.325234  0.332907
# 2998   999  16.0  788.617879  733.720636  0.235553  0.289817
# 2999   999  32.0  774.893569  719.996326  0.214856  0.337194
#
# [3000 rows x 6 columns]

# %%
colors ={'8': '#87263c', '16': '#bb5566', '32': '#f08494'} # KAne
colors ={'8': '#a77b00', '16': '#ddaa33', '32': '#ffdb65'} # AixNet
colors = {'8': '#007a6b', '16': '#44aa99', '32': '#78dcca'} # Universality

c_aix = 'DDAA33'
c_kane = '#BB5566'
c_univ = '#44AA99'
c_herald = 'darkred'
c_light = 'deeppink'
c_heavy = 'blue'
c_alt_light = 'palevioletred'
c_alt_heavy = 'royalblue'
c_total = 'k'
c_fd_fit = 'black'
c_fd_rel = '#004488'
energ = [8, 16, 32, 200]
# plt.figure(figsize=(10,6))
# for i in range(len(energ[:-1])):
#     ene = energ[i]
#     plt.hist(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)], histtype='step', stacked=True, fill=False, color=colors[f'{ene}'], lw=4, alpha=0.8)
#     plt.axvline(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_l'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
#     print(np.mean(df['frac_l'][(df['emin']==ene)&(df['frac_l']!=0)]))
# plt.legend()
# plt.xlim(0.01, 0.8)
# plt.xlabel('fraction of lightest events')
# plt.ylabel('# simulated data sets')
# plt.show()


# plt.figure(figsize=(10,6))
# for i in range(len(energ[:-1])):
#     ene = energ[i]
#     plt.hist(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)], histtype='step', fill=False, color=colors[f'{ene}'], lw=4, alpha=0.8)
#     plt.axvline(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['frac_h'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
#     print(np.mean(df['frac_h'][(df['emin']==ene)&(df['frac_h']!=0)]))
# plt.legend()
# plt.xlim(0.01, 0.8)
# plt.xlabel('fraction of heaviest events')
# plt.ylabel('# simulated data sets')
# plt.show()


# da ChatGPT perché sono pigro cazzo
fig, axs = plt.subplots(1, 2, figsize=(27, 9))
fig.suptitle('AixNet (old EPOS simulations)', size=40)

# First plot: fraction of lightest events
for i in range(len(energ[:-1])):
    ene = energ[i]
    data_l = df['frac_l'][(df['emin'] == ene)]
    mean_l = np.mean(data_l)
    axs[0].hist(data_l, histtype='step', stacked=True, fill=False,
                color=colors[f'{ene}'], lw=8, bins=10, alpha=0.9, density=True)
    axs[0].axvline(mean_l, ls='--', lw=4, color=colors[f'{ene}'],
                   label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_l:.3f}$')
    # print(mean_l)

axs[0].legend()
axs[0].set_xlim(0.01, 0.8)
axs[0].set_xlabel('fraction of lightest events')
axs[0].set_ylabel('# simulated data sets')

# Second plot: fraction of heaviest events
for i in range(len(energ[:-1])):
    ene = energ[i]
    data_h = df['frac_h'][(df['emin'] == ene)]
    mean_h = np.mean(data_h)
    axs[1].hist(data_h, histtype='step', fill=False,
                color=colors[f'{ene}'], lw=8, bins=10, alpha=0.9, density=True)
    axs[1].axvline(mean_h, ls='--', lw=4, color=colors[f'{ene}'],
                   label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {mean_h:.3f}$')
    # print(mean_h)

axs[1].legend()
axs[1].set_xlim(0.01, 0.8)
axs[1].set_xlabel('fraction of heaviest events')

plt.tight_layout()
plt.show()


print(len(df['frac_l'][(df['frac_l']!=0)]))
# Out:
# 3000

# %%
colors ={'8': 'red', '16': 'green', '32': 'blue'}
energ = [8, 16, 32, 200]
plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['light'][df['emin']==ene], histtype='step', stacked=False, fill=False, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['light'][df['emin']==ene]))
plt.legend()
# plt.xlim(700.1, 850)
plt.xlabel(r'light threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()


plt.figure(figsize=(10,6))
for i in range(len(energ[:-1])):
    ene = energ[i]
    plt.hist(df['heavy'][df['emin']==ene], histtype='step', fill=False, color=colors[f'{ene}'], lw=4, alpha=0.5)
    plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
    print(np.mean(df['heavy'][df['emin']==ene]))
plt.legend()
# plt.xlim(710.1, 825)
plt.xlabel(r'heavy threshold $/ \, \mathrm{\left(g \, cm^{-2}\right)}$')
plt.ylabel('# simulated data sets')
plt.show()
# Out:
# 798.148329660967
# 787.7764516686248
# 775.2708956409346
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# <>:7: SyntaxWarning: invalid escape sequence '\,'
# <>:20: SyntaxWarning: invalid escape sequence '\,'
# /tmp/ipykernel_12350/3093058098.py:7: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['light'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['light'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# /tmp/ipykernel_12350/3093058098.py:20: SyntaxWarning: invalid escape sequence '\,'
#   plt.axvline(np.mean(df['heavy'][df['emin']==ene]), ls='--', lw=4, label=f'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}}: {np.mean(df['heavy'][df['emin']==ene]):.2f}$', color=colors[f'{ene}'])
# 748.0783359737468
# 738.5771524500981
# 726.3807876875314

# %%
from scipy import stats

# colors = {'8': '#007a6b', '16': '#44aa99', '32': '#78dcca'}
colors ={'8': '#ffdb65', '16': '#ddaa33', '32': '#a77b00'} # AixNet 

energ = [8, 16, 32, 200]
bins = np.linspace(-5, 10, num=25)

plt.figure(figsize=(15,9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['heavy'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4, label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.1f} ({p16:.1f}, {p84:.1f}), mode: {mode[0]:.1f}', color=colors[f'{ene}'])
    # plt.fill_betweenx([0, plt.gca().get_ylim()[1]], p16, p84, color=colors[f'{ene}'], alpha=0.2)

    print(f"{ene} EeV heavy median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")
plt.legend(fontsize='small')
plt.xlabel(r'light $\ln A$ threshold')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 400)
plt.show()


plt.figure(figsize=(15,9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['light'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', stacked=False, fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4, label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.1f} ({p16:.1f}, {p84:.1f}), mode: {mode[0]:.1f}', color=colors[f'{ene}'])
    # plt.fill_betweenx([0, plt.gca().get_ylim()[1]], p16, p84, color=colors[f'{ene}'], alpha=0.2)

    print(f"{ene} EeV light median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")
plt.legend(fontsize='small')
plt.xlabel(r'heavy $\ln A$ threshold')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 400)
plt.show()
# Out:
# 8 EeV heavy median: 748.53, 68% interval: [742.13, 753.80]
# 16 EeV heavy median: 738.56, 68% interval: [733.59, 743.68]
# 32 EeV heavy median: 725.99, 68% interval: [721.72, 731.54]
# 8 EeV light median: 797.50, 68% interval: [790.61, 805.61]
# 16 EeV light median: 788.13, 68% interval: [781.75, 794.18]
# 32 EeV light median: 774.82, 68% interval: [768.70, 781.70]

# %%
bins = np.linspace(0, 1, num=25)
# fig, ax = plt.subplots(1, 2, figsize=(18, 9), sharey=True)
# First subplot: light
plt.figure(figsize=(15, 9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['frac_h'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4,
                  label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.2f} ({p16:.2f}, {p84:.2f}), mode: {mode[0]:.2f}',
                  color=colors[f'{ene}'])
    print(f"{ene} EeV heavy median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")

plt.legend(fontsize='small')
plt.xlabel(r'fraction of heaviest events')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 700)
plt.show()
# ax[0].set_ylim(0, 0.7)

# Second subplot: heavy
plt.figure(figsize=(15, 9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['frac_l'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', stacked=False, fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4,
                  label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.2f} ({p16:.2f}, {p84:.2f}), mode: {mode[0]:.2f}',
                  color=colors[f'{ene}'])
    print(f"{ene} EeV light median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")

plt.legend(fontsize='small')
plt.xlabel(r'fraction of lightest events')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 700)
plt.show()
# Out:
# 8 EeV heavy median: 0.34, 68% interval: [0.29, 0.39]
# 16 EeV heavy median: 0.34, 68% interval: [0.29, 0.38]
# 32 EeV heavy median: 0.39, 68% interval: [0.35, 0.45]
# 8 EeV light median: 0.27, 68% interval: [0.22, 0.31]
# 16 EeV light median: 0.25, 68% interval: [0.21, 0.29]
# 32 EeV light median: 0.21, 68% interval: [0.18, 0.25]

# %%
from scipy import stats

energ = [8, 16, 32, 200]
bins = np.linspace(700, 850, num=25)

plt.figure(figsize=(15,9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['heavy'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4, label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.0f} ({p16:.0f}, {p84:.0f}), mode: {mode[0]:.0f}', color=colors[f'{ene}'])
    # plt.fill_betweenx([0, plt.gca().get_ylim()[1]], p16, p84, color=colors[f'{ene}'], alpha=0.2)

    print(f"{ene} EeV heavy median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")
plt.legend(fontsize='small')
plt.xlabel(r'heavy threshold / (g cm$^{-2}$)')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 500)
plt.show()


plt.figure(figsize=(15,9))
for i in range(len(energ[:-1])):
    ene = energ[i]
    data = df['light'][df['emin'] == ene]
    median = np.median(data)
    mode = stats.mode(data)
    p16, p84 = np.percentile(data, [16, 84])
    
    plt.hist(data, histtype='step', stacked=False, fill=False, color=colors[f'{ene}'], lw=8, alpha=0.9, bins=bins)
    plt.axvline(median, ls='--', lw=4, label=rf'$[{ene}, {energ[i+1]}] \, \mathrm{{EeV}},$ median: {median:.0f} ({p16:.0f}, {p84:.0f}), mode: {mode[0]:.0f}', color=colors[f'{ene}'])
    # plt.fill_betweenx([0, plt.gca().get_ylim()[1]], p16, p84, color=colors[f'{ene}'], alpha=0.2)

    print(f"{ene} EeV light median: {median:.2f}, 68% interval: [{p16:.2f}, {p84:.2f}]")
plt.legend(fontsize='small', loc='upper left')
plt.xlabel(r'light threshold / (g cm$^{-2}$)')
plt.ylabel('# of simulated data sets')
plt.ylim(0, 500)
plt.show()
# Out:
# 8 EeV heavy median: 748.53, 68% interval: [742.13, 753.80]
# 16 EeV heavy median: 738.56, 68% interval: [733.59, 743.68]
# 32 EeV heavy median: 725.99, 68% interval: [721.72, 731.54]
# 8 EeV light median: 797.50, 68% interval: [790.61, 805.61]
# 16 EeV light median: 788.13, 68% interval: [781.75, 794.18]
# 32 EeV light median: 774.82, 68% interval: [768.70, 781.70]

# %%
# frac_emily_l = [0.195, 0.134, 0.087]
# frac_emily_h = [0.50, 0.57, 0.463]

# frac_lna_l = [0.16, 0.09, 0.04]
# sigma_lna_l =[[0.09, 0.23], [0.04, 0.17], [0.02, 0.17]]

# frac_lna_h = [0.52, 0.49, 0.52]
# sigma_lna_h = [[0.40, 0.64], [0.39, 0.60], [0.21, 0.67]]

# frac_xm_l = [0.16, 0.09, 0.06]
# sigma_xm_l = [[0.09, 0.23], [0.03, 0.15], [0.03, 0.13]]

# frac_xm_h = [0.53, 0.50, 0.56]
# sigma_xm_h = [[0.38, 0.63], [0.39, 0.63], [0.25, 0.68]]

# frac_aix_l = [0.22, 0.14, 0.14]
# sigma_aix_l = [[0.12, 0.29], [0.10, 0.21], [0.09, 0.18]]

# frac_aix_h = [0.35, 0.51, 0.47]
# sigma_aix_h = [[0.26, 0.45], [0.41, 0.61], [0.32, 0.64]]

# titles = ['$[8, 16] \, \mathrm{EeV}$', '$[16, 32] \, \mathrm{EeV}$', '$> 32 \, \mathrm{EeV}$']

# colors ={'8': '#87263c', '16': '#bb5566', '32': '#f08494'} # KAne
# colors ={'8': '#a77b00', '16': '#ddaa33', '32': '#ffdb65'} # AixNet
# colors = {'8': '#007a6b', '16': '#44aa99', '32': '#78dcca'} # Universality

# print(np.abs(frac_aix_l[0]-np.array(sigma_aix_l[0])))
# # plot for comparison
# for i in range(3):
#     plt.figure(figsize=(10,6))
#     plt.title(r'$[8, 16] \, \mathrm{EeV}$')
#     plt.axhline(frac_emily_l[i], lw=4, ls='--', label='Emily light', color='deeppink')
#     plt.axhline(frac_emily_h[i], lw=4, ls='--', label='Emily heavy', color='blue')
#     plt.errorbar(1, frac_lna_l[i], yerr=np.abs(frac_lna_l[i]-np.array(sigma_lna_l[i])), lw=4, color='#007a6b', label='lnA light')
#     plt.errorbar(1, frac_lna_h[i], yerr=np.abs(frac_lna_h[i]-np.array(sigma_lna_h[i])), lw=4, color='#78dcca', label='lnA light')

    
#     plt.show()
